# %% [markdown]
# # Видобуток та збагачення структурованих даних

# %% [markdown]
# ### ТЕОРЕТИЧНА ЧАСТИНА ТА ПРИКЛАДИ

# %% [markdown]
# Для роботи з структурованими табличними даними, які розміщені в реляційній БД [SQLite](https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&cad=rja&uact=8&ved=2ahUKEwiUyMOv1orvAhWDK3cKHac9DyMQFjAAegQIBxAD&url=https%3A%2F%2Fru.wikipedia.org%2Fwiki%2FSQLite&usg=AOvVaw1s-RMK2VC2tXyDZxZXDYDo) в Python передбачена стандартна бібліотека [sqlite3](https://docs.python.org/3/library/sqlite3.html)

# %%
# підключення бібліотеки
import sqlite3

# %% [markdown]
# #### ПРИКЛАД ВИЛУЧЕННЯ ДАНИХ З БД
# Створити БД SQLite з ім'ям `FIT-4m`, та імпорувати в неї таблицю, що містить журнал групи `jornal`

# %%
# створюємо з'єднання з БД
conn = sqlite3.connect("FIT-4m.db")

# %% [markdown]
# [імпорт csv файла в sqlite через CLI](https://www.sqlitetutorial.net/sqlite-import-csv/)

# %%
# створюємо об'єкт `cursor`, що відповідає за реалізацію операцій з таблицями БД
cur = conn.cursor()

# %%
print(type(cur), end='\n\n')
print(dir(cur))

# %% [markdown]
# ##### виведемо ВСІ записи таблиці `jornal`

# %%
# створимо інстанс для операції `SELECT`
students_cur = cur.execute("SELECT * FROM jornal")

# будуємо список записів за допомогою метода `fetchall()`
students_list = students_cur.fetchall()

_ = [print(x) for x in students_list]

# %% [markdown]
# #### ПРИКЛАД ЗБАГАЧЕННЯ ДАНИХ З ЗОВНІШНЬОГО ДЖЕРЕЛА
#
# Додати до списка студентів їх оцінки за вступне тестування, які розташовані в csv файлі `test_result.csv`

# %% [markdown]
# імпортуємо `test_result.csv` в робочу БД як таблицю `test`
#
# [імпорт csv файла в sqlite через CLI](https://www.sqlitetutorial.net/sqlite-import-csv/)

# %% [markdown]
# ##### Cтворимо нову таблицю, яка буде містити вміст таблиці `jornal` та поле оцінок з таблиці `test`

# %%
# створимо вираз на побудову пустої таблиці `jornal_test` з відповідними полями
sql_stmt = "CREATE TABLE IF NOT EXISTS jornal_test \
              (Surname TEXT,         \
               Name TEXT,            \
               Email TEXT,           \
               GitHub TEXT,          \
               Test_result INT);"

# виконаемо запит на створення таблиці
cur.execute(sql_stmt)

# %%
# перевіримо стан виконання операції - виведемо список таблиць
tables_list = cur.execute("SELECT name FROM sqlite_master WHERE type = 'table';")
tables_list.fetchall()

# %%
# створимо запит на об'єднання таблиць 'jornal' та 'test' по прізвищу студента
sql_stmt = "SELECT jornal.*, test_result.test FROM  \
            jornal LEFT JOIN test_result ON jornal.Surname = test_result.Surname "

# %%
# для перевірки виконаємо і виведемо результати запиту
cur.execute(sql_stmt).fetchmany(7)

# %%
# заповнимо пусту таблицю результатми  запиту на злиття
_ = cur.execute("INSERT INTO jornal_test " + sql_stmt)

# %%
# збережемо вміст нової таблиці в список
jornal_test_list = cur.execute("SELECT * FROM jornal_test").fetchall()

_ = [print(x) for x in jornal_test_list]

# %%
# завершимо всі транзакції
conn.commit()

# закріємо з'єднання
conn.close()

# %% [markdown]
# #### ПРИКЛАД  ДЕСКРИПТИВНОГО АНАЛІЗУ ДАНИХ
#
# Провести [попередній аналіз](https://ru.wikipedia.org/wiki/Описательная_статистика) отриманих даних з ціллю виявленя відхилень, помилок та інших непридатних даних.

# %% [markdown]
# Сведемо результати аналізу в таблицю, яка має наступний вигляд:
#
# №| Показчик | Значення
# :--:|:-------|-------:
# 1| кількість спостережень | xx
# 2| кількість пустих значень | xx
# 4| середній бал|  xx.x
# 5| максимальний бал | xx
# 6| мінімальний бал  | xx
# 7| стандартне відхилення | xx.x
# 8| розмах вариації  | xx

# %%
# підключимо бібліотеку 'numpy' і дамо їй аліас 'np'
import numpy as np

# %% [markdown]
# ознайомитись з призначенням, можливостями та основним функціями [бібліотеки numpy](https://numpy.org)

# %%
# перетворимо список студетів в numpay матрицю
jornal_test_arr = np.array(jornal_test_list)

# %%
print(type (jornal_test_arr), jornal_test_arr.shape)

# %%
# створимо масив с результатами тестів 
test_result = np.delete(jornal_test_arr, [1,2,3], axis=1)

# %%
# Значення 'None' - не є числом, то заміним його на 0
test_result[test_result == None] = 0

# %%
# залишити тільки статистично важливі показчики
test_result = np.delete(test_result, 0, axis=1)

# %%
# будуємо словник з вихідними розрахунками
result_dict = {
    "кількість спостережень"   : len(test_result),
    "кількість пустих значень" : len(test_result) - np.count_nonzero(test_result),
    "середній бал"             : round(np.mean(test_result),1),
    "максимальний бал"         : np.max(test_result),
    "мінімальний бал"          : np.min(test_result[np.nonzero(test_result)]),
    "стандартне відхилення"    : round(np.std(test_result),1),
    "розмах вариації"          : np.max(test_result) - np.min(test_result[np.nonzero(test_result)]) 
    }

# %%
result_dict

# %%
# вивести шапку
print(
"""
=======================================
№  : ПОКАЗЧИК               : ЗНАЧЕННЯ     
=======================================
"""      
      )

# вивести результати аналізу датасета
i = 1
for key, value in result_dict.items():
    print (f'{i:<3} {key:<25}  {value}')
    i += 1

# %% [markdown]
# ### ІНДИВІДУАЛЬНЕ ЗАВДАННЯ

# %% [markdown]
# Користуючись результатами, що отримані в [Лабораторній роботі № 3](https://shkliarskiy.moodlecloud.com/mod/page/view.php?id=1193) виконати процедури видобутку, збагачення та попереднього аналізу даних.
#
# __Постановка__: В 3-й лабораторній роботі отримано показчик, що характеризує окрему властивість квартири (ціна, метраж та ін.).
# Необхідно:
# 1. Відобразити цей показчик на адресу квартири, яка знаходиться в файлі `street_name.csv`, тобто побудувати новий файл `street_flat_propery.csv` якій містить 2 колонки: _<назва вулиці> <ваш показчик>_
# 2. На основі цьго файлу зробити відповідну таблицю в _SQLite_ та збагатити цю дані в цій таблиці назвою району де розташована квартира (дані по районах додаються)
# 3. Провести попередній аналіз отриманих даних - вивести первинні статистики показчика по районах (_середне_ , _мінімальне_ , _максимальне_ і т.д. - див. приклад вище)

# %%
# Злиття файлу з показчиком та файлу з назвами вулиць в новий файл
import os
import numpy as np

path = 'D:\DM-stas\LB4\Data'
filenames = []

for root, dirs, files in os.walk(path): 
    for file in files:  
        filenames.append(path +  "\\" + file)

with open('D:\DM-stas\LB4\street_name.csv', 'r', encoding='utf-8') as f1, \
    open('D:\DM-stas\LB4\street_flat_propery.csv', 'w') as f3:     
    f1_lines = f1.readlines()
    for line_index in range (0, len(f1_lines)):     
        element = f1_lines[line_index].split()   

        if(not element or element[0] == '***'):
            result = "No street name" + ","
        else:
            f1_splited = f1_lines[line_index].split()
            result = f1_splited[0] + "," 

        for fname in filenames:
            with open(fname) as f2:
                f2_lines = f2.readlines()
                f2_splited = f2_lines[line_index].split()

                result+= f2_splited[0] + ","
                                                
        f3.write(result[:-1] + '\n')
        

        
jornal_test_list = cur.execute("SELECT * from street_flat_propery").fetchall()
jornal_test_arr = np.array(jornal_test_list)

x_result = np.delete(jornal_test_arr, [0], axis=1)

length = x_result.shape

for j in range(0, length[1]):
    test_result = x_result[:,j].astype(float)
    
    result_dict = {
    "кількість спостережень"   : len(test_result),
    "кількість пустих значень" : len(test_result) - np.count_nonzero(test_result),
    "середній бал"             : round(np.mean(test_result),1),
    "максимальний бал"         : np.max(test_result),
    "мінімальний бал"          : np.min(test_result[np.nonzero(test_result)]),
    "стандартне відхилення"    : round(np.std(test_result),1),
    "розмах вариації"          : np.max(test_result) - np.min(test_result[np.nonzero(test_result)]) 
    }
    
    columns_names = cur.execute("PRAGMA table_info('street_flat_propery')").fetchall()
    print("Назва таблиці: " + columns_names[j][1])
    
    print(
"""
=======================================
№  : ПОКАЗЧИК               : ЗНАЧЕННЯ     
=======================================
"""      
      )

    i = 1
    for key, value in result_dict.items():
        print (f'{i:<3} {key:<25}  {value}')
        i += 1
    print('\n')
# Out:
# Назва таблиці: street
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     728
# 2   кількість пустих значень   36
# 3   середній бал               9.4
# 4   максимальний бал           29.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      7.2
# 7   розмах вариації            28.0
#
#
# Назва таблиці: aprt_level
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     728
# 2   кількість пустих значень   139
# 3   середній бал               34.2
# 4   максимальний бал           300.0
# 5   мінімальний бал            10.0
# 6   стандартне відхилення      31.5
# 7   розмах вариації            290.0
#
#
# Назва таблиці: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     728
# 2   кількість пустих значень   25
# 3   середній бал               2939.1
# 4   максимальний бал           73902.0
# 5   мінімальний бал            534.0
# 6   стандартне відхилення      7208.7
# 7   розмах вариації            73368.0
#
#
# Назва таблиці: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     728
# 2   кількість пустих значень   0
# 3   середній бал               162149.7
# 4   максимальний бал           4500000.0
# 5   мінімальний бал            2918.9189189189187
# 6   стандартне відхилення      265791.8
# 7   розмах вариації            4497081.081081081
#
#
# Назва таблиці: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     728
# 2   кількість пустих значень   2
# 3   середній бал               2.2
# 4   максимальний бал           10.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      1.1
# 7   розмах вариації            9.0
#
#
# Назва таблиці: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     728
# 2   кількість пустих значень   1
# 3   середній бал               81.0
# 4   максимальний бал           555.0
# 5   мінімальний бал            21.31
# 6   стандартне відхилення      50.5
# 7   розмах вариації            533.69
#
#
# Назва таблиці: aprt_total_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     728
# 2   кількість пустих значень   36
# 3   середній бал               16.5
# 4   максимальний бал           36.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      8.8
# 7   розмах вариації            35.0
#
#
# Назва таблиці: aprt_total_levels
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     728
# 2   кількість пустих значень   211
# 3   середній бал               1418.5
# 4   максимальний бал           2022.0
# 5   мінімальний бал            1858.0
# 6   стандартне відхилення      906.5
# 7   розмах вариації            164.0

# %% [markdown]
# #### імпортувати в БД отриманий файл 'street_flat_propery.csv' через CLI
# - __sqlite3 districts.db__ - запустити SQLite та відкрити БД
# - __.mode csv__ - перевести БД для роботи з csv-файлами
# - __.import street_flat_propery.csv street_flat_propery__ - створює таблицю _street_flat_propery_ та завантажує в неї вміст файлу _street_flat_propery.csv_
# - __SELECT * FROM street_flat_propery LIMIT 10;__ - вивести 10 записів для перевірки
# - __.quit__ - завершити роботу з CLI SQLite

# %%
# Підключитись до БД 'districts.db' в якій є прив'язка вулиць до районів 
import sqlite3

conn = sqlite3.connect("districts.db")

cur = conn.cursor()

streets_cur = cur.execute("SELECT * FROM street_district")

# %%
# для перевірки виведіть 10 записів з таблиці 'street_district'


streets_cur = cur.execute("SELECT * FROM street_district")

streets_list = streets_cur.fetchmany(10)

_ = [print(street) for street in streets_list]
# Out:
# ('9-го Травня', 'вулиця', 'Святошинський')
# ('Абрикосова', 'вулиця', 'Оболонський')
# ('Абрикосова', 'вулиця', 'Дарницький')
# ('Абрикосова', 'вулиця', 'Подільський')
# ('Августина Волошина', 'вулиця', 'Солом’янський')
# ('Авдєєнка Генерала', 'вулиця', 'Святошинський')
# ('Автозаводська', 'вулиця', 'Оболонський')
# ('Автозаводський ', 'провулок', 'Оболонський')
# ('Автопаркова', 'вулиця', 'Дарницький')
# ('Авторемонтна', 'вулиця', "Солом'янський")

# %%
# побудувати запит на створення таблиці 'result' з 3-ма полями:
#     district - текстове
#     street - текстове
#     property - числове


sql_stmt = "CREATE TABLE IF NOT EXISTS result \
              (district TEXT,         \
               street TEXT,            \
               property INT);"

cur.execute(sql_stmt)

tables_list = cur.execute("SELECT name FROM sqlite_master WHERE type = 'table';")
tables_list.fetchall()
# Out:
# [('street_district',),
#  ('result',),
#  ('street_flat_propery',),
#  ('street_result',)]

# %%
# перевірити схему таблиці
cur.execute ("SELECT name FROM PRAGMA_TABLE_INFO('result');").fetchall()
# Out:
# [('district',), ('street',), ('property',)]

# %%
# створити запит на злиття таблиці 'street_flat_propery' та 'street_district' 
# по полю 'street'
# створимо запит на об'єднання таблиць 'jornal' та 'test' по прізвищу студента
stmt_join = "SELECT street_flat_propery.*, street_district.type, street_district.district FROM   \
            street_flat_propery LEFT JOIN street_district ON street_flat_propery.street = street_district.street "

# %%
# перевірити запит
cur.execute(stmt_join).fetchall()
# Out:
# [('Омеляновича-Павленка',
#   21,
#   37,
#   1575.0,
#   115000.0,
#   2,
#   73,
#   25,
#   2015,
#   None,
#   None),
#  ('No street name', 11, 58, 680.0, 75000.0, 3, 110.27, 25, 0, None, None),
#  ('Ованеса', 5, 56, 1400.0, 140000.0, 3, 100, 18, 2011, None, None),
#  ('Петропавлівська',
#   5,
#   32,
#   2414.0,
#   140000.0,
#   2,
#   58,
#   5,
#   1902,
#   'вулиця',
#   'Подільський'),
#  ('Петропавлівська',
#   5,
#   32,
#   2414.0,
#   140000.0,
#   2,
#   58,
#   5,
#   1902,
#   'площа',
#   'Оболонський'),
#  ('Дніпровська',
#   2,
#   36,
#   2025.0,
#   160000.0,
#   2,
#   79,
#   10,
#   2014,
#   'вулиця',
#   'Оболонський'),
#  ('Саксаганського',
#   2,
#   77.6,
#   6273.0,
#   870000.0,
#   3,
#   138.7,
#   22,
#   2009,
#   'вулиця',
#   'Голосіївський, Печерський, Шевченківський'),
#  ('Івана',
#   21,
#   115,
#   73902.0,
#   402266.5675675676,
#   5,
#   201.4,
#   23,
#   2018,
#   None,
#   None),
#  ('Дніпровська',
#   4,
#   43,
#   2529.0,
#   220000.0,
#   2,
#   87,
#   23,
#   2012,
#   'вулиця',
#   'Оболонський'),
#  ('Ділова',
#   6,
#   10,
#   3325.0,
#   133000.0,
#   1,
#   40,
#   20,
#   2017,
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('Новодарницька', 2, 29, 1353.0, 69000.0, 2, 51, 9, 1980, None, None),
#  ('Ревуцького',
#   8,
#   20,
#   3542.0,
#   169999.0,
#   1,
#   48,
#   19,
#   2012,
#   'вулиця',
#   'Дарницький'),
#  ('Липківського', 2, 40.1, 2494.0, 212000.0, 2, 85, 17, 0, None, None),
#  ('Бендукідзе', 13, 33.4, 1099.0, 83500.0, 2, 76, 25, 2018, None, None),
#  ('Введенська',
#   12,
#   32.9,
#   1339.0,
#   75000.0,
#   2,
#   56,
#   12,
#   1985,
#   'вулиця',
#   'Подільський'),
#  ('Виноградний',
#   12,
#   16,
#   1711.0,
#   65000.0,
#   1,
#   38,
#   25,
#   2017,
#   'провулок',
#   'Печерський'),
#  ('Кайсарова',
#   5,
#   44,
#   1171.0,
#   82000.0,
#   3,
#   70,
#   9,
#   1981,
#   'вулиця',
#   "Голосіївський,Солом'янський"),
#  ('Ахматової', 16, 63, 2010.0, 207000.0, 3, 103, 18, 2016, None, None),
#  ('Радченка', 4, 29, 921.0, 51990.0, 2, 56.44, 6, 0, None, None),
#  ('Дніпровська',
#   3,
#   42,
#   841.0,
#   57999.0,
#   3,
#   69,
#   10,
#   1987,
#   'вулиця',
#   'Оболонський'),
#  ('Ділова',
#   21,
#   16.21,
#   1203.0,
#   57000.0,
#   2,
#   47.39,
#   24,
#   0,
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('Бориспільська',
#   3,
#   28,
#   1900.0,
#   95000.0,
#   1,
#   50,
#   23,
#   2016,
#   'вулиця',
#   'Дарницький'),
#  ('Болсуновська',
#   8,
#   45,
#   781.0,
#   50000.0,
#   3,
#   64,
#   9,
#   1976,
#   'вулиця',
#   'Печерський'),
#  ('Українки', 5, 64, 990.0, 95000.0, 4, 96, 5, 1960, None, None),
#  ('Антонова', 5, 32, 1019.0, 46860.0, 2, 46, 5, 1966, None, None),
#  ('Омеляновича-Павленка', 3, 28, 875.0, 38500.0, 2, 44, 5, 1964, None, None),
#  ('No street name', 7, 50, 1100.0, 110000.0, 3, 100, 12, 2008, None, None),
#  ('Ованеса', 14, 125, 1121.0, 269000.0, 5, 240, 15, 0, None, None),
#  ('Петропавлівська',
#   6,
#   35.59,
#   27503.0,
#   53594.59459459459,
#   2,
#   72.1,
#   25,
#   0,
#   'вулиця',
#   'Подільський'),
#  ('Петропавлівська',
#   6,
#   35.59,
#   27503.0,
#   53594.59459459459,
#   2,
#   72.1,
#   25,
#   0,
#   'площа',
#   'Оболонський'),
#  ('Дніпровська',
#   19,
#   35,
#   1587.0,
#   119000.0,
#   2,
#   75,
#   25,
#   2007,
#   'вулиця',
#   'Оболонський'),
#  ('Саксаганського',
#   1,
#   50,
#   2692.0,
#   210000.0,
#   3,
#   78,
#   5,
#   1916,
#   'вулиця',
#   'Голосіївський, Печерський, Шевченківський'),
#  ('Івана', 7, 64.6, 2460.0, 310000.0, 3, 126, 16, 0, None, None),
#  ('Дніпровська',
#   12,
#   50,
#   1000.0,
#   93000.0,
#   3,
#   93,
#   18,
#   0,
#   'вулиця',
#   'Оболонський'),
#  ('Ділова',
#   6,
#   32,
#   1556.0,
#   98000.0,
#   2,
#   63,
#   16,
#   2013,
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('Новодарницька', 1, 25, 1773.0, 78000.0, 2, 44, 4, 2019, None, None),
#  ('Ревуцького',
#   24,
#   28.54,
#   1001.0,
#   68000.0,
#   2,
#   67.92,
#   26,
#   0,
#   'вулиця',
#   'Дарницький'),
#  ('Липківського', 11, 21, 1481.0, 77000.0, 1, 52, 17, 2009, None, None),
#  ('Бендукідзе', 5, 48.1, 1778.0, 176000.0, 3, 99, 25, 2017, None, None),
#  ('Введенська',
#   9,
#   50,
#   58042.0,
#   150594.5945945946,
#   3,
#   96,
#   12,
#   0,
#   'вулиця',
#   'Подільський'),
#  ('Виноградний',
#   3,
#   0,
#   1985.0,
#   129000.0,
#   3,
#   65,
#   4,
#   0,
#   'провулок',
#   'Печерський'),
#  ('Кайсарова',
#   15,
#   0,
#   2720.0,
#   136000.0,
#   2,
#   50,
#   25,
#   2016,
#   'вулиця',
#   "Голосіївський,Солом'янський"),
#  ('Ахматової', 3, 41, 934.0, 71000.0, 3, 76, 9, 1986, None, None),
#  ('Радченка', 15, 0, 2384.0, 108000.0, 1, 45.3, 25, 2019, None, None),
#  ('Дніпровська',
#   9,
#   50,
#   1768.0,
#   175000.0,
#   4,
#   99,
#   9,
#   1977,
#   'вулиця',
#   'Оболонський'),
#  ('Ділова',
#   17,
#   53.2,
#   602.0,
#   45006.0,
#   3,
#   74.7,
#   17,
#   0,
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('Бориспільська',
#   22,
#   0,
#   1322.0,
#   78000.0,
#   2,
#   59,
#   25,
#   2018,
#   'вулиця',
#   'Дарницький'),
#  ('Болсуновська',
#   1,
#   42,
#   890.0,
#   65000.0,
#   3,
#   73,
#   9,
#   1983,
#   'вулиця',
#   'Печерський'),
#  ('Українки', 14, 0, 54774.0, 91783.7837837838, 2, 62, 25, 0, None, None),
#  ('Антонова', 5, 50, 907.0, 68899.0, 3, 76, 5, 1963, None, None),
#  ('Науки',
#   12,
#   20,
#   2697.0,
#   205000.0,
#   2,
#   76,
#   23,
#   2014,
#   'проспект',
#   'Голосіївський'),
#  ('Метрологічна',
#   4,
#   69,
#   1005.0,
#   211000.0,
#   3,
#   210,
#   4,
#   1906,
#   'вулиця',
#   'Голосіївський'),
#  ('Дружби', 5, 18, 1106.0, 36500.0, 1, 33, 5, 1962, 'вулиця', 'Дарницький'),
#  ('No street name',
#   16,
#   17.96,
#   47556.0,
#   85857.16216216216,
#   1,
#   66.8,
#   26,
#   0,
#   None,
#   None),
#  ('Драгомирова', 14, 40, 2500.0, 155000.0, 2, 62, 24, 2017, None, None),
#  ('Данченка', 13, 65.8, 1068.0, 109000.0, 3, 102.1, 25, 2009, None, None),
#  ('Кримська',
#   3,
#   54,
#   1091.0,
#   120000.0,
#   3,
#   110,
#   16,
#   2002,
#   'вулиця',
#   'Голосіївський'),
#  ('Новопольова',
#   10,
#   31,
#   1078.0,
#   55000.0,
#   2,
#   51,
#   10,
#   1990,
#   'вулиця',
#   "Солом'янський"),
#  ('Туполєва', 7, 30, 1091.0, 48000.0, 2, 44, 9, 1971, None, None),
#  ('No street name', 6, 44, 2582.0, 235000.0, 2, 91, 24, 2010, None, None),
#  ('Дніпровська',
#   9,
#   17,
#   1464.0,
#   41000.0,
#   1,
#   28,
#   9,
#   1969,
#   'вулиця',
#   'Оболонський'),
#  ('Перемоги',
#   10,
#   0,
#   2554.0,
#   143000.0,
#   1,
#   56,
#   11,
#   0,
#   'вулиця',
#   'Святошинський'),
#  ('Перемоги',
#   10,
#   0,
#   2554.0,
#   143000.0,
#   1,
#   56,
#   11,
#   0,
#   'площа',
#   'Шевченківський'),
#  ('Перемоги',
#   10,
#   0,
#   2554.0,
#   143000.0,
#   1,
#   56,
#   11,
#   0,
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('Івана', 9, 39.7, 966.0, 65000.0, 3, 67.3, 9, 1983, None, None),
#  ('Братиславська',
#   2,
#   45,
#   5000.0,
#   500000.0,
#   3,
#   100,
#   5,
#   1892,
#   'вулиця',
#   'Деснянський, Дніпровський'),
#  ('No street name', 3, 50, 1146.0, 94000.0, 3, 82, 5, 0, None, None),
#  ('Червоноткацька', 3, 0, 2295.0, 280000.0, 3, 122, 24, 2006, None, None),
#  ('Златоустівська', 5, 19, 1500.0, 67500.0, 1, 45, 9, 2017, None, None),
#  ('Бойченка', 0, 0, 960.0, 72000.0, 2, 75, 0, 0, None, None),
#  ('Трускавецька',
#   29,
#   0,
#   1588.0,
#   54000.0,
#   1,
#   34,
#   33,
#   0,
#   'вулиця',
#   'Дарницький'),
#  ('Каховська', 2, 30, 1609.0, 74000.0, 2, 46, 8, 0, 'вулиця', 'Дніпровський'),
#  ('Лобановського', 16, 46.7, 1300.0, 130000.0, 2, 100, 24, 2008, None, None),
#  ('No street name', 4, 60, 1111.0, 110000.0, 3, 99, 25, 2010, None, None),
#  ('Курчатова', 3, 41, 2400.0, 180000.0, 3, 75, 8, 1990, None, None),
#  ('Голосіївська',
#   21,
#   0,
#   1113.0,
#   69000.0,
#   2,
#   62,
#   25,
#   2018,
#   'вулиця',
#   'Голосіївський'),
#  ('Голосіївська',
#   21,
#   0,
#   1113.0,
#   69000.0,
#   2,
#   62,
#   25,
#   2018,
#   'площа',
#   'Голосіївський'),
#  ('Тираспольська',
#   12,
#   20,
#   2697.0,
#   205000.0,
#   2,
#   76,
#   23,
#   2014,
#   'вулиця',
#   'Подільський'),
#  ('Лаврська',
#   4,
#   69,
#   1005.0,
#   211000.0,
#   3,
#   210,
#   4,
#   1906,
#   'вулиця',
#   'Печерський'),
#  ('Правди', 5, 18, 1106.0, 36500.0, 1, 33, 5, 1962, 'проспект', 'Подільський'),
#  ('Миколайчука',
#   16,
#   17.96,
#   47556.0,
#   85857.16216216216,
#   1,
#   66.8,
#   26,
#   0,
#   None,
#   None),
#  ('Порика', 14, 40, 2500.0, 155000.0, 2, 62, 24, 2017, None, None),
#  ('Червоноткацька',
#   13,
#   65.8,
#   1068.0,
#   109000.0,
#   3,
#   102.1,
#   25,
#   2009,
#   None,
#   None),
#  ('Маккейна', 3, 54, 1091.0, 120000.0, 3, 110, 16, 2002, None, None),
#  ('Йорданська',
#   10,
#   31,
#   1078.0,
#   55000.0,
#   2,
#   51,
#   10,
#   1990,
#   'вулиця',
#   'Оболонський'),
#  ('Тютюнника', 7, 30, 1091.0, 48000.0, 2, 44, 9, 1971, None, None),
#  ('Регенераторна',
#   6,
#   44,
#   2582.0,
#   235000.0,
#   2,
#   91,
#   24,
#   2010,
#   'вулиця',
#   'Дніпровський'),
#  ('Зарічна', 9, 17, 1464.0, 41000.0, 1, 28, 9, 1969, 'вулиця', 'Дарницький'),
#  ('Заболотного', 10, 0, 2554.0, 143000.0, 1, 56, 11, 0, None, None),
#  ('Курнатовського',
#   9,
#   39.7,
#   966.0,
#   65000.0,
#   3,
#   67.3,
#   9,
#   1983,
#   'вулиця',
#   'Дніпровський, Деснянський'),
#  ('Інститутська',
#   2,
#   45,
#   5000.0,
#   500000.0,
#   3,
#   100,
#   5,
#   1892,
#   'вулиця',
#   'Печерський'),
#  ('Маланюка', 3, 50, 1146.0, 94000.0, 3, 82, 5, 0, None, None),
#  ('Гречка', 3, 0, 2295.0, 280000.0, 3, 122, 24, 2006, None, None),
#  ('Липківського', 5, 19, 1500.0, 67500.0, 1, 45, 9, 2017, None, None),
#  ('Маккейна', 0, 0, 960.0, 72000.0, 2, 75, 0, 0, None, None),
#  ('Григоренка', 29, 0, 1588.0, 54000.0, 1, 34, 33, 0, None, None),
#  ('Коновальця', 2, 30, 1609.0, 74000.0, 2, 46, 8, 0, None, None),
#  ('Закревського', 16, 46.7, 1300.0, 130000.0, 2, 100, 24, 2008, None, None),
#  ('No street name', 4, 60, 1111.0, 110000.0, 3, 99, 25, 2010, None, None),
#  ('Старонаводницька',
#   3,
#   41,
#   2400.0,
#   180000.0,
#   3,
#   75,
#   8,
#   1990,
#   'вулиця',
#   'Печерський'),
#  ('Маланюка', 21, 0, 1113.0, 69000.0, 2, 62, 25, 2018, None, None),
#  ('Заньковецької',
#   6,
#   42,
#   1667.0,
#   120000.0,
#   3,
#   72,
#   6,
#   1994,
#   'вулиця',
#   'Печерський'),
#  ('Кудрявська',
#   7,
#   58,
#   1290.0,
#   150000.0,
#   3,
#   116.3,
#   22,
#   2016,
#   'вулиця',
#   'Шевченківський'),
#  ('No street name', 10, 0, 4717.0, 750000.0, 4, 159, 10, 2014, None, None),
#  ('Українки', 2, 58, 987.0, 75000.0, 3, 76, 5, 1959, None, None),
#  ('No street name', 5, 27, 1120.0, 53000.0, 1, 47.32, 16, 1990, None, None),
#  ('Милославська',
#   2,
#   30,
#   966.0,
#   42500.0,
#   2,
#   44,
#   5,
#   1962,
#   'вулиця',
#   'Деснянський'),
#  ('Донця', 2, 45, 1084.0, 103000.0, 3, 95, 13, 2017, None, None),
#  ('Верховинця', 23, 180, 2708.0, 650000.0, 5, 240, 23, 2013, None, None),
#  ('Героїв', 2, 21, 1556.0, 56000.0, 1, 36, 15, 0, None, None),
#  ('Каховська',
#   7,
#   0,
#   1800.0,
#   90000.0,
#   1,
#   50,
#   25,
#   1969,
#   'вулиця',
#   'Дніпровський'),
#  ('Каховська',
#   11,
#   32,
#   1085.0,
#   77000.0,
#   2,
#   71,
#   16,
#   0,
#   'вулиця',
#   'Дніпровський'),
#  ('Вишняківська',
#   4,
#   16,
#   1901.0,
#   115000.0,
#   2,
#   60.51,
#   5,
#   2020,
#   'вулиця',
#   'Дарницький'),
#  ('Липська', 6, 42, 1488.0, 120000.0, 2, 80.66, 22, 0, None, None),
#  ('Сверстюка', 9, 75, 1057.0, 130000.0, 3, 123, 27, 2004, None, None),
#  ('Драгомирова', 4, 29.5, 1149.0, 85000.0, 2, 74, 22, 2008, None, None),
#  ('Причальна',
#   18,
#   31,
#   1728.0,
#   140000.0,
#   2,
#   81,
#   25,
#   2018,
#   'вулиця',
#   'Дарницький'),
#  ('Болсуновська',
#   5,
#   18,
#   1058.0,
#   45500.0,
#   1,
#   43,
#   25,
#   2013,
#   'вулиця',
#   'Печерський'),
#  ('Повітрофлотський',
#   3,
#   40,
#   753.0,
#   63232.0,
#   3,
#   84,
#   18,
#   0,
#   'проспект',
#   "Шевченківський, Солом'янський"),
#  ('Драгоманова',
#   3,
#   0,
#   2065.0,
#   95000.0,
#   2,
#   46,
#   24,
#   2017,
#   'вулиця',
#   'Дарницький'),
#  ('Григоренка', 5, 18, 1000.0, 55000.0, 1, 55, 24, 2020, None, None),
#  ('Дніпровська',
#   23,
#   80,
#   1374.0,
#   186900.0,
#   3,
#   136,
#   25,
#   2011,
#   'вулиця',
#   'Оболонський'),
#  ('Жабаєва', 3, 15, 1605.0, 34200.0, 1, 21.31, 28, 0, None, None),
#  ('Філатова', 8, 50, 1727.0, 234899.0, 3, 136, 9, 2018, None, None),
#  ('Правди', 9, 0, 1341.0, 55000.0, 1, 41, 25, 2019, 'проспект', 'Подільський'),
#  ('Малопідвальна',
#   3,
#   33.1,
#   1915.0,
#   136000.0,
#   2,
#   71,
#   10,
#   2019,
#   'вулиця',
#   'Шевченківський'),
#  ('Бойчука', 3, 20, 2439.0, 139000.0, 2, 57, 6, 1957, None, None),
#  ('Зарічна',
#   7,
#   87,
#   1409.0,
#   210000.0,
#   3,
#   149,
#   12,
#   2001,
#   'вулиця',
#   'Дарницький'),
#  ('Предславинська',
#   5,
#   17,
#   3900.0,
#   195000.0,
#   1,
#   50,
#   16,
#   2017,
#   'вулиця',
#   'Печерський'),
#  ('Івана', 3, 46, 1587.0, 119000.0, 3, 75, 25, 2018, None, None),
#  ('Радченка', 11, 0, 4457.0, 410000.0, 3, 92, 26, 2013, None, None),
#  ('Лабораторний',
#   17,
#   30,
#   1550.0,
#   93000.0,
#   2,
#   60,
#   22,
#   2007,
#   'провулок',
#   'Печерський'),
#  ('Конєва', 19, 47.72, 1939.0, 137634.0, 2, 70.99, 19, 0, None, None),
#  ('Шаповала', 4, 16, 1901.0, 115000.0, 2, 60.51, 5, 2020, None, None),
#  ('Дніпровська',
#   19,
#   0,
#   1545.0,
#   85000.0,
#   1,
#   55,
#   25,
#   0,
#   'вулиця',
#   'Оболонський'),
#  ('Клеманська',
#   6,
#   48,
#   1566.0,
#   130000.0,
#   3,
#   83,
#   10,
#   2013,
#   'вулиця',
#   'Дарницький'),
#  ('Григоренка', 4, 20, 2055.0, 113000.0, 1, 55, 20, 2015, None, None),
#  ('Туполєва', 23, 0, 1097.0, 39500.0, 1, 36, 25, 0, None, None),
#  ('Хмельницького', 9, 40, 1046.0, 68000.0, 3, 65, 9, 1963, None, None),
#  ('Саперне', 3, 43, 1384.0, 155000.0, 3, 112, 25, 2019, None, None),
#  ('Героїв', 3, 32.1, 2200.0, 110000.0, 2, 50, 3, 2013, None, None),
#  ('Дніпровська',
#   12,
#   28.78,
#   1103.0,
#   75000.0,
#   2,
#   68,
#   24,
#   0,
#   'вулиця',
#   'Оболонський'),
#  ('Тарасівська',
#   2,
#   42,
#   1671.0,
#   142000.0,
#   3,
#   85,
#   15,
#   2018,
#   'вулиця',
#   'Голосіївський'),
#  ('Краківська',
#   6,
#   30,
#   1569.0,
#   80000.0,
#   2,
#   51,
#   9,
#   1981,
#   'вулиця',
#   'Дніпровський'),
#  ('Юнацька', 4, 22, 935.0, 43000.0, 2, 46, 4, 0, 'вулиця', 'Святошинський'),
#  ('Юнацька', 4, 22, 935.0, 43000.0, 2, 46, 4, 0, 'вулиця', "Солом'янський"),
#  ('Клеманська',
#   10,
#   95,
#   1198.0,
#   248000.0,
#   5,
#   207,
#   14,
#   2015,
#   'вулиця',
#   'Дарницький'),
#  ('Героїв', 8, 73, 2154.0, 280000.0, 3, 130, 11, 2005, None, None),
#  ('Драгомирова', 2, 40, 2580.0, 209000.0, 2, 81, 10, 2003, None, None),
#  ('No street name', 3, 13, 1439.0, 58990.0, 1, 41, 32, 0, None, None),
#  ('Драгоманова',
#   23,
#   29,
#   2220.0,
#   111000.0,
#   1,
#   50,
#   25,
#   2019,
#   'вулиця',
#   'Дарницький'),
#  ('Українки', 2, 41, 1796.0, 97000.0, 3, 54, 9, 1971, None, None),
#  ('Тимошенка', 7, 0, 819.0, 68000.0, 3, 83, 25, 0, None, None),
#  ('Маяковського',
#   3,
#   50,
#   2283.0,
#   184900.0,
#   3,
#   81,
#   13,
#   1980,
#   'вулиця',
#   'Деснянський'),
#  ('Дмитрівська',
#   3,
#   30,
#   1398.0,
#   61500.0,
#   2,
#   44,
#   5,
#   1959,
#   'вулиця',
#   'Подільський'),
#  ('Дмитрівська',
#   3,
#   30,
#   1398.0,
#   61500.0,
#   2,
#   44,
#   5,
#   1959,
#   'вулиця',
#   'Шевченківський'),
#  ('Курбаса', 2, 47, 1233.0, 111000.0, 3, 90, 25, 2014, None, None),
#  ('Комарова', 11, 0, 2414.0, 190700.0, 2, 79, 11, 0, None, None),
#  ('Драгоманова',
#   21,
#   13.61,
#   1233.0,
#   53000.0,
#   1,
#   43,
#   24,
#   0,
#   'вулиця',
#   'Дарницький'),
#  ('Драгомирова', 2, 29, 1353.0, 69000.0, 2, 51, 9, 1980, None, None),
#  ('Моторний', 7, 75.2, 1340.0, 169000.0, 4, 126.1, 8, 2019, None, None),
#  ('Милославська',
#   10,
#   29,
#   1730.0,
#   95000.0,
#   2,
#   54.9,
#   16,
#   1993,
#   'вулиця',
#   'Деснянський'),
#  ('Бойчука', 13, 52, 1000.0, 110000.0, 3, 110, 18, 2003, None, None),
#  ('Закревського',
#   22,
#   46.5,
#   55472.0,
#   158918.9189189189,
#   5,
#   106,
#   25,
#   2017,
#   None,
#   None),
#  ('Івана', 5, 47, 1389.0, 99999.0, 3, 72, 22, 1996, None, None),
#  ('Філатова', 17, 0, 2680.0, 327000.0, 4, 122, 20, 0, None, None),
#  ('Перемоги', 13, 0, 1269.0, 85000.0, 2, 67, 34, 0, 'вулиця', 'Святошинський'),
#  ('Перемоги', 13, 0, 1269.0, 85000.0, 2, 67, 34, 0, 'площа', 'Шевченківський'),
#  ('Перемоги',
#   13,
#   0,
#   1269.0,
#   85000.0,
#   2,
#   67,
#   34,
#   0,
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('Миропільська',
#   6,
#   240,
#   2894.0,
#   790000.0,
#   6,
#   273,
#   6,
#   1914,
#   'вулиця',
#   'Деснянський, Дніпровський'),
#  ('Григоренка', 11, 48, 1145.0, 95000.0, 3, 83, 16, 2005, None, None),
#  ('Юнацька', 9, 17, 1556.0, 70000.0, 1, 45, 16, 0, 'вулиця', 'Святошинський'),
#  ('Юнацька', 9, 17, 1556.0, 70000.0, 1, 45, 16, 0, 'вулиця', "Солом'янський"),
#  ('Вишгородська',
#   1,
#   0,
#   31530.0,
#   63570.86486486487,
#   3,
#   74.6,
#   4,
#   0,
#   'вулиця',
#   'Подільський, Оболонський'),
#  ('Жолудєва',
#   1,
#   0,
#   30000.0,
#   21810.81081081081,
#   1,
#   26.9,
#   5,
#   0,
#   'вулиця',
#   'Святошинський'),
#  ('Павлівська',
#   17,
#   15,
#   1571.0,
#   77000.0,
#   1,
#   49,
#   26,
#   0,
#   'вулиця',
#   'Шевченківський'),
#  ('Голосіївський',
#   11,
#   41.8,
#   892.0,
#   75000.0,
#   2,
#   84.1,
#   11,
#   1999,
#   'провулок',
#   'Голосіївський'),
#  ('Голосіївський',
#   11,
#   41.8,
#   892.0,
#   75000.0,
#   2,
#   84.1,
#   11,
#   1999,
#   'проспект',
#   'Голосіївський'),
#  ('Осокорська',
#   4,
#   103,
#   2623.0,
#   480000.0,
#   4,
#   183,
#   5,
#   2007,
#   'вулиця',
#   'Дарницький'),
#  ('Вишгородська',
#   10,
#   20.8,
#   1449.0,
#   70000.0,
#   1,
#   48.3,
#   24,
#   2009,
#   'вулиця',
#   'Подільський, Оболонський'),
#  ('Драгомирова', 12, 20, 2697.0, 205000.0, 2, 76, 23, 2014, None, None),
#  ('Тютюнника', 5, 0, 3125.0, 499990.0, 3, 160, 11, 2005, None, None),
#  ('Маккейна', 5, 10.28, 1274.0, 52000.0, 1, 40.82, 16, 2017, None, None),
#  ('Івана', 7, 26.9, 1563.0, 93000.0, 1, 59.5, 14, 2007, None, None),
#  ('Героїв', 9, 29, 1603.0, 117000.0, 3, 73, 16, 0, None, None),
#  ('Липківського', 23, 14.6, 1152.0, 53900.0, 1, 46.79, 25, 0, None, None),
#  ('No street name', 15, 18, 1318.0, 58000.0, 1, 44, 24, 2015, None, None),
#  ('Коновальця', 12, 35.6, 2120.0, 159000.0, 2, 75, 25, 0, None, None),
#  ('Максимовича',
#   22,
#   21,
#   1933.0,
#   116000.0,
#   2,
#   60,
#   26,
#   2014,
#   'вулиця',
#   'Святошинський'),
#  ('Зарічна', 6, 18, 1235.0, 42000.0, 1, 34, 9, 1977, 'вулиця', 'Дарницький'),
#  ('Голосіївська',
#   6,
#   41,
#   854.0,
#   55500.0,
#   3,
#   65,
#   9,
#   1974,
#   'вулиця',
#   'Голосіївський'),
#  ('Голосіївська',
#   6,
#   41,
#   854.0,
#   55500.0,
#   3,
#   65,
#   9,
#   1974,
#   'площа',
#   'Голосіївський'),
#  ('Ясинуватський',
#   5,
#   0,
#   1947.0,
#   370000.0,
#   3,
#   190,
#   24,
#   2005,
#   'провулок',
#   'Голосіївський'),
#  ('No street name', 8, 78, 2708.0, 650000.0, 4, 240, 8, 1958, None, None),
#  ('Колоса', 0, 0, 4176.0, 355000.0, 3, 85, 0, 0, None, None),
#  ('Правди',
#   2,
#   36,
#   3021.0,
#   145000.0,
#   1,
#   48,
#   24,
#   2017,
#   'проспект',
#   'Подільський'),
#  ('Велика', 2, 39.6, 1560.0, 117000.0, 2, 75, 25, 2018, None, None),
#  ('Голосіївський',
#   1,
#   38,
#   5000.0,
#   300000.0,
#   2,
#   60,
#   6,
#   2005,
#   'провулок',
#   'Голосіївський'),
#  ('Голосіївський',
#   1,
#   38,
#   5000.0,
#   300000.0,
#   2,
#   60,
#   6,
#   2005,
#   'проспект',
#   'Голосіївський'),
#  ('No street name', 7, 19, 1107.0, 55000.0, 1, 49.7, 22, 2012, None, None),
#  ('Бойчука', 2, 31, 869.0, 41000.0, 2, 47.18, 5, 1964, None, None),
#  ('Центральна',
#   3,
#   18,
#   2560.0,
#   128000.0,
#   2,
#   50,
#   25,
#   2015,
#   'вулиця',
#   'Дніпровський'),
#  ('Центральна',
#   3,
#   18,
#   2560.0,
#   128000.0,
#   2,
#   50,
#   25,
#   2015,
#   'вулиця',
#   'Оболонський'),
#  ('Центральна',
#   3,
#   18,
#   2560.0,
#   128000.0,
#   2,
#   50,
#   25,
#   2015,
#   'вулиця',
#   'Шевченківський'),
#  ('Ясинуватський',
#   2,
#   0,
#   2465.0,
#   175000.0,
#   2,
#   71,
#   25,
#   2017,
#   'провулок',
#   'Голосіївський'),
#  ('Райдужна',
#   3,
#   13,
#   25808.0,
#   21162.162162162163,
#   1,
#   30.34,
#   5,
#   0,
#   'вулиця',
#   'Дніпровський'),
#  ('Ломоносова',
#   23,
#   36,
#   1324.0,
#   90000.0,
#   2,
#   68,
#   25,
#   2011,
#   'вулиця',
#   'Голосіївський'),
#  ('No street name', 3, 0, 2227.0, 98000.0, 2, 44, 5, 1964, None, None),
#  ('No street name', 15, 13.4, 2854.0, 137000.0, 1, 48, 23, 2016, None, None),
#  ('Гусовського', 7, 0, 978.0, 45000.0, 1, 46, 26, 0, 'вулиця', 'Печерський'),
#  ('Окіпної',
#   19,
#   28.3,
#   31537.0,
#   54465.62162162162,
#   2,
#   63.9,
#   26,
#   2021,
#   None,
#   None),
#  ('Багговутівська',
#   3,
#   62.5,
#   2163.0,
#   200000.0,
#   3,
#   92.48,
#   5,
#   1946,
#   'вулиця',
#   'Шевченківський'),
#  ('Дружби', 9, 0, 2333.0, 147000.0, 2, 63, 24, 2017, 'вулиця', 'Дарницький'),
#  ('Маккейна', 5, 42, 1099.0, 78000.0, 3, 71, 9, 1977, None, None),
#  ('Маланюка', 15, 13, 2343.0, 82000.0, 1, 35, 15, 2018, None, None),
#  ('Михайла', 4, 35, 1562.0, 75000.0, 1, 48, 6, 0, None, None),
#  ('Героїв', 15, 27.2, 1589.0, 89000.0, 1, 56, 20, 2013, None, None),
#  ('Маланюка', 7, 0, 3447.0, 710000.0, 4, 206, 25, 2015, None, None),
#  ('Саперне', 14, 93, 3605.0, 620000.0, 5, 172, 17, 2001, None, None),
#  ('Балтійський',
#   1,
#   22,
#   1544.0,
#   69500.0,
#   3,
#   45,
#   7,
#   0,
#   'провулок',
#   'Оболонський'),
#  ('Кудрявська',
#   8,
#   45,
#   1000.0,
#   85000.0,
#   2,
#   85,
#   25,
#   2015,
#   'вулиця',
#   'Шевченківський'),
#  ('Перемоги', 6, 17, 878.0, 43000.0, 2, 49, 6, 0, 'вулиця', 'Святошинський'),
#  ('Перемоги', 6, 17, 878.0, 43000.0, 2, 49, 6, 0, 'площа', 'Шевченківський'),
#  ('Перемоги',
#   6,
#   17,
#   878.0,
#   43000.0,
#   2,
#   49,
#   6,
#   0,
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('Німанська',
#   16,
#   80,
#   1710.0,
#   330000.0,
#   4,
#   193,
#   16,
#   2003,
#   'вулиця',
#   'Печерський'),
#  ('Каховська',
#   2,
#   26,
#   1429.0,
#   59000.0,
#   2,
#   41.3,
#   9,
#   1963,
#   'вулиця',
#   'Дніпровський'),
#  ('Малопідвальна',
#   1,
#   31,
#   930.0,
#   40000.0,
#   3,
#   43,
#   5,
#   1962,
#   'вулиця',
#   'Шевченківський'),
#  ('Невська', 4, 178, 3429.0, 1200000.0, 5, 350, 6, 1895, None, None),
#  ('Златоустівська', 20, 0, 3189.0, 405000.0, 3, 127, 31, 0, None, None),
#  ('No street name', 4, 0, 1285.0, 100110.0, 3, 77.9, 16, 0, None, None),
#  ('Берковецька',
#   12,
#   86.6,
#   2222.0,
#   400000.0,
#   4,
#   180,
#   25,
#   2001,
#   'вулиця',
#   'Святошинський'),
#  ('Бажана', 16, 15.08, 1788.0, 97500.0, 1, 54.54, 26, 0, None, None),
#  ('Антоновича',
#   0,
#   0,
#   0.0,
#   83000.0,
#   0,
#   0,
#   0,
#   0,
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('No street name', 2, 40, 733.0, 44000.0, 3, 60, 5, 1970, None, None),
#  ('Гречка', 8, 40.6, 1100.0, 66000.0, 3, 60, 9, 1973, None, None),
#  ('Микільсько-Слобідська',
#   2,
#   95,
#   2011.0,
#   350000.0,
#   4,
#   174,
#   10,
#   0,
#   'вулиця',
#   'Дніпровський'),
#  ('Правди',
#   15,
#   29,
#   1055.0,
#   77000.0,
#   2,
#   73,
#   25,
#   2010,
#   'проспект',
#   'Подільський'),
#  ('Тимошенка', 22, 52, 1315.0, 122250.0, 3, 93, 24, 0, None, None),
#  ('Павла', 6, 42.3, 888.0, 65000.0, 3, 73.2, 9, 1979, None, None),
#  ('Олевська',
#   4,
#   80,
#   1214.0,
#   170000.0,
#   4,
#   140,
#   16,
#   2002,
#   'вулиця',
#   'Святошинський'),
#  ('Освіти',
#   13,
#   18,
#   1900.0,
#   95000.0,
#   1,
#   50,
#   25,
#   2018,
#   'вулиця',
#   "Солом'янський"),
#  ('Іллєнка', 3, 46, 966.0, 85000.0, 3, 88, 16, 2005, None, None),
#  ('Дніпровська',
#   25,
#   15.6,
#   1454.0,
#   69500.0,
#   1,
#   47.8,
#   25,
#   0,
#   'вулиця',
#   'Оболонський'),
#  ('Івана', 9, 20, 3535.0, 152000.0, 2, 43, 24, 2019, None, None),
#  ('Українки', 6, 42, 1278.0, 92000.0, 3, 72, 9, 1975, None, None),
#  ('Данченка', 27, 0, 1518.0, 375000.0, 6, 247, 27, 2010, None, None),
#  ('Драгомирова', 12, 170, 1796.0, 449000.0, 5, 250, 16, 2005, None, None),
#  ('Тбіліський', 9, 32, 1127.0, 75500.0, 2, 67, 25, 2020, None, None),
#  ('Каховська',
#   9,
#   34.19,
#   1728.0,
#   140000.0,
#   2,
#   81,
#   9,
#   1986,
#   'вулиця',
#   'Дніпровський'),
#  ('Ушинського', 0, 0, 1364.0, 45000.0, 1, 33, 0, 0, 'вулиця', "Солом'янський"),
#  ('Ушинського',
#   0,
#   0,
#   1364.0,
#   45000.0,
#   1,
#   33,
#   0,
#   0,
#   'провулок',
#   "Солом'янський"),
#  ('Урлівська',
#   11,
#   18,
#   2316.0,
#   135000.0,
#   1,
#   58.3,
#   15,
#   2005,
#   'вулиця',
#   'Дарницький'),
#  ('Світлицького',
#   26,
#   50,
#   1344.0,
#   125000.0,
#   4,
#   93,
#   33,
#   2018,
#   'вулиця',
#   'Подільський'),
#  ('Дніпровська',
#   21,
#   56,
#   1284.0,
#   140000.0,
#   3,
#   109,
#   25,
#   2011,
#   'вулиця',
#   'Оболонський'),
#  ('Липківського', 14, 34.5, 1713.0, 120000.0, 2, 70.05, 16, 2018, None, None),
#  ('Микільсько-Слобідська',
#   1,
#   30,
#   764.0,
#   42000.0,
#   2,
#   55,
#   5,
#   1971,
#   'вулиця',
#   'Дніпровський'),
#  ('Лобановського', 3, 41, 1420.0, 125000.0, 3, 88, 24, 2020, None, None),
#  ('Героїв', 4, 31.4, 1086.0, 48000.0, 2, 44.2, 5, 1960, None, None),
#  ('Дніпровська',
#   16,
#   91,
#   2000.0,
#   300000.0,
#   3,
#   150,
#   17,
#   2005,
#   'вулиця',
#   'Оболонський'),
#  ('Драгоманова',
#   20,
#   61,
#   1379.0,
#   120000.0,
#   3,
#   87,
#   24,
#   0,
#   'вулиця',
#   'Дарницький'),
#  ('Ахматової', 11, 150, 2360.0, 649000.0, 5, 275, 17, 2006, None, None),
#  ('Саперне', 4, 56, 812.0, 64980.0, 4, 80, 9, 1969, None, None),
#  ('Данченка', 16, 22, 1426.0, 77000.0, 1, 54, 24, 2015, None, None),
#  ('Голосіївський',
#   24,
#   14,
#   1116.0,
#   48000.0,
#   1,
#   43,
#   26,
#   0,
#   'провулок',
#   'Голосіївський'),
#  ('Голосіївський',
#   24,
#   14,
#   1116.0,
#   48000.0,
#   1,
#   43,
#   26,
#   0,
#   'проспект',
#   'Голосіївський'),
#  ('No street name', 2, 47, 1085.0, 102000.0, 3, 94, 22, 2006, None, None),
#  ('Глибочицька',
#   22,
#   15,
#   4405.0,
#   185000.0,
#   1,
#   42,
#   24,
#   2019,
#   'вулиця',
#   'Шевченківський'),
#  ('Багговутівська',
#   10,
#   17.5,
#   1243.0,
#   42000.0,
#   1,
#   33.8,
#   22,
#   0,
#   'вулиця',
#   'Шевченківський'),
#  ('Саксаганського',
#   16,
#   55,
#   991.0,
#   115000.0,
#   3,
#   116,
#   19,
#   2007,
#   'вулиця',
#   'Голосіївський, Печерський, Шевченківський'),
#  ('Моторний', 4, 33, 2303.0, 175000.0, 2, 76, 14, 0, None, None),
#  ('Йорданська',
#   9,
#   40,
#   915.0,
#   54000.0,
#   3,
#   59,
#   9,
#   1973,
#   'вулиця',
#   'Оболонський'),
#  ('Саперне', 12, 68, 50580.0, 273405.4054054054, 4, 200, 12, 2012, None, None),
#  ('Вернадського', 18, 15.7, 1957.0, 137000.0, 2, 70, 24, 2017, None, None),
#  ('Курбаса', 12, 40.6, 1258.0, 95000.0, 3, 75.5, 20, 1997, None, None),
#  ('Багговутівська',
#   5,
#   120,
#   2400.0,
#   360000.0,
#   5,
#   150,
#   6,
#   1936,
#   'вулиця',
#   'Шевченківський'),
#  ('Набережно-Рибальська',
#   6,
#   86,
#   833.0,
#   135000.0,
#   1,
#   162,
#   16,
#   2005,
#   'дорога',
#   'Подільський'),
#  ('Саксаганського',
#   1,
#   18,
#   2333.0,
#   105000.0,
#   1,
#   45,
#   9,
#   1971,
#   'вулиця',
#   'Голосіївський, Печерський, Шевченківський'),
#  ('Малиновського', 4, 27, 935.0, 58000.0, 2, 62, 26, 0, None, None),
#  ('Протасів', 3, 45, 2400.0, 180000.0, 5, 75, 4, 1883, None, None),
#  ('Німанська',
#   8,
#   42,
#   1692.0,
#   153000.0,
#   2,
#   90.4,
#   27,
#   2010,
#   'вулиця',
#   'Печерський'),
#  ('Підвисоцького', 6, 37, 2271.0, 159000.0, 2, 70, 12, 2016, None, None),
#  ('Зодчих',
#   6,
#   53,
#   1032.0,
#   98000.0,
#   3,
#   95,
#   25,
#   2016,
#   'вулиця',
#   'Святошинський'),
#  ('Рокосовського', 25, 0, 2162.0, 1200000.0, 0, 555, 25, 2001, None, None),
#  ('Шовковична',
#   11,
#   15.3,
#   1140.0,
#   42900.0,
#   1,
#   37.62,
#   26,
#   0,
#   'вулиця',
#   'Печерський'),
#  ('Крушельницької', 6, 31, 925.0, 86000.0, 3, 93, 8, 2015, None, None),
#  ('Новопольова',
#   5,
#   22,
#   2818.0,
#   155000.0,
#   1,
#   55,
#   19,
#   0,
#   'вулиця',
#   "Солом'янський"),
#  ('Визволителів',
#   15,
#   0,
#   4412.0,
#   450000.0,
#   3,
#   102,
#   30,
#   0,
#   'проспект',
#   'Дніпровський'),
#  ('Сонячна',
#   0,
#   53.22,
#   1574.0,
#   148000.0,
#   3,
#   94,
#   0,
#   0,
#   'вулиця',
#   'Дніпровський'),
#  ('Сонячна',
#   0,
#   53.22,
#   1574.0,
#   148000.0,
#   3,
#   94,
#   0,
#   0,
#   'вулиця',
#   'Шевченківський'),
#  ('Сікорського', 4, 18, 1220.0, 50000.0, 1, 41, 5, 0, None, None),
#  ('Радченка', 5, 60, 1045.0, 81000.0, 3, 77.5, 26, 0, None, None),
#  ('Бульварно-Кудрявська',
#   5,
#   53.21,
#   1830.0,
#   161003.0,
#   3,
#   87.98,
#   23,
#   2013,
#   'вулиця',
#   'Шевченківський'),
#  ('Кайсарова',
#   20,
#   28.74,
#   933.0,
#   61500.0,
#   2,
#   65.91,
#   26,
#   0,
#   'вулиця',
#   "Голосіївський,Солом'янський"),
#  ('Дніпровська',
#   13,
#   30,
#   1164.0,
#   78000.0,
#   2,
#   67,
#   24,
#   0,
#   'вулиця',
#   'Оболонський'),
#  ('Перова',
#   7,
#   71.2,
#   2038.0,
#   259266.0,
#   3,
#   127.24,
#   9,
#   0,
#   'бульвар',
#   'Дніпровський'),
#  ('Глушкова', 5, 15, 1113.0, 34500.0, 1, 31, 9, 1982, None, None),
#  ('Рокосовського', 21, 40.24, 1402.0, 122000.0, 3, 87, 22, 0, None, None),
#  ('Саперно-Слобідська',
#   21,
#   0,
#   1798.0,
#   147420.0,
#   2,
#   82,
#   25,
#   0,
#   'вулиця',
#   'Голосіївський'),
#  ('Миколи', 1, 20, 1460.0, 73000.0, 2, 50, 9, 1983, None, None),
#  ('Миколи', 11, 16, 1100.0, 44000.0, 1, 40, 26, 0, None, None),
#  ('Антоновича',
#   2,
#   48,
#   1829.0,
#   128000.0,
#   3,
#   70,
#   4,
#   0,
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('Богданівська',
#   2,
#   31,
#   1480.0,
#   111000.0,
#   1,
#   75,
#   10,
#   2013,
#   'вулиця',
#   "Солом'янський"),
#  ('No street name', 9, 53, 760.0, 73000.0, 3, 96, 20, 2014, None, None),
#  ('Сверстюка', 15, 27.2, 1589.0, 89000.0, 1, 56, 20, 2013, None, None),
#  ('Ревуцького',
#   14,
#   0,
#   1488.0,
#   64000.0,
#   1,
#   43,
#   25,
#   2019,
#   'вулиця',
#   'Дарницький'),
#  ('Ованеса', 0, 0, 3151.0, 375000.0, 3, 119, 0, 0, None, None),
#  ('Саперне', 4, 29, 2279.0, 98000.0, 1, 43, 4, 1905, None, None),
#  ('Григоренка', 8, 12.3, 1455.0, 32000.0, 1, 22, 9, 0, None, None),
#  ('Гречка', 16, 57, 1190.0, 125000.0, 3, 105, 24, 2012, None, None),
#  ('Богатирська',
#   3,
#   30,
#   1398.0,
#   61500.0,
#   2,
#   44,
#   5,
#   1959,
#   'вулиця',
#   'Оболонський'),
#  ('Білоруська',
#   16,
#   33,
#   1522.0,
#   105000.0,
#   2,
#   69,
#   25,
#   2016,
#   'вулиця',
#   'Шевченківський'),
#  ('Регенераторна',
#   0,
#   0,
#   0.0,
#   65557.83783783784,
#   1,
#   45,
#   0,
#   0,
#   'вулиця',
#   'Дніпровський'),
#  ('Вишняківська', 9, 45, 937.0, 89000.0, 3, 95, 13, 0, 'вулиця', 'Дарницький'),
#  ('Гонгадзе', 9, 16, 982.0, 27500.0, 1, 28, 9, 1973, None, None),
#  ('Правди', 5, 18, 1175.0, 47000.0, 1, 40, 25, 0, 'проспект', 'Подільський'),
#  ('Кольцова',
#   3,
#   101,
#   2043.0,
#   329000.0,
#   3,
#   161,
#   17,
#   2009,
#   'бульвар',
#   'Святошинський'),
#  ('Воскресенська',
#   17,
#   0,
#   710.0,
#   71000.0,
#   3,
#   100,
#   35,
#   0,
#   'вулиця',
#   'Дніпровський'),
#  ('Руставелі', 0, 0, 0.0, 50957.59459459459, 2, 65, 0, 0, None, None),
#  ('Голосіївський',
#   10,
#   150,
#   4601.0,
#   980000.0,
#   5,
#   213,
#   13,
#   2003,
#   'провулок',
#   'Голосіївський'),
#  ('Голосіївський',
#   10,
#   150,
#   4601.0,
#   980000.0,
#   5,
#   213,
#   13,
#   2003,
#   'проспект',
#   'Голосіївський'),
#  ('Комбінатна',
#   6,
#   35,
#   1097.0,
#   68000.0,
#   2,
#   62,
#   9,
#   1971,
#   'вулиця',
#   'Дніпровський'),
#  ('Салютна', 9, 27, 1127.0, 71000.0, 2, 63, 24, 0, 'вулиця', 'Шевченківський'),
#  ('Маланюка', 14, 0, 2111.0, 190000.0, 2, 90, 16, 1983, None, None),
#  ('Ромоданова', 0, 0, 0.0, 98429.2972972973, 1, 39, 0, 0, None, None),
#  ('Саперне', 21, 37, 1575.0, 115000.0, 2, 73, 25, 2015, None, None),
#  ('Сім’ї', 10, 19, 1324.0, 45000.0, 1, 34, 16, 1982, None, None),
#  ('Лабораторна',
#   21,
#   19,
#   1140.0,
#   57000.0,
#   1,
#   50,
#   27,
#   0,
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('Драгоманова',
#   4,
#   27,
#   1167.0,
#   45500.0,
#   2,
#   39,
#   5,
#   1961,
#   'вулиця',
#   'Дарницький'),
#  ('No street name', 5, 25, 4727.0, 260000.0, 2, 55, 24, 2019, None, None),
#  ('Кудрявська',
#   12,
#   26,
#   1379.0,
#   80000.0,
#   1,
#   58,
#   25,
#   0,
#   'вулиця',
#   'Шевченківський'),
#  ('Краківська',
#   0,
#   0,
#   0.0,
#   57033.83783783784,
#   1,
#   52,
#   0,
#   0,
#   'вулиця',
#   'Дніпровський'),
#  ('Кольцова',
#   6,
#   50,
#   1500.0,
#   138000.0,
#   3,
#   92,
#   26,
#   2018,
#   'бульвар',
#   'Святошинський'),
#  ('Антоновича',
#   7,
#   33,
#   1544.0,
#   105000.0,
#   2,
#   68,
#   25,
#   2016,
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('Лариси',
#   12,
#   37.23,
#   27900.0,
#   63868.37837837838,
#   2,
#   84.7,
#   26,
#   2020,
#   None,
#   None),
#  ('Івана', 12, 15, 1369.0, 89000.0, 2, 65, 20, 2018, None, None),
#  ('Українки', 19, 73, 2759.0, 400000.0, 3, 145, 24, 2012, None, None),
#  ('Тютюнника', 9, 32, 1724.0, 100000.0, 2, 58, 17, 2006, None, None),
#  ('Юрія', 14, 43, 809.0, 61500.0, 3, 76, 16, 1989, None, None),
#  ('Оболонський',
#   18,
#   18,
#   1043.0,
#   48000.0,
#   1,
#   46,
#   24,
#   0,
#   'проспект',
#   'Оболонський'),
#  ('Курбаса', 23, 62, 2045.0, 180000.0, 2, 88, 25, 2015, None, None),
#  ('Верховинця',
#   8,
#   46.7,
#   1158.0,
#   2918.9189189189187,
#   3,
#   93.3,
#   24,
#   2014,
#   None,
#   None),
#  ('Зарічна', 21, 18, 1046.0, 43500.0, 1, 41.6, 24, 0, 'вулиця', 'Дарницький'),
#  ('Дніпровська',
#   3,
#   16.3,
#   1741.0,
#   100999.0,
#   1,
#   58,
#   15,
#   2004,
#   'вулиця',
#   'Оболонський'),
#  ('Коломийський',
#   24,
#   0,
#   1000.0,
#   52000.0,
#   1,
#   52,
#   25,
#   0,
#   'провулок',
#   'Голосіївський'),
#  ('Правди',
#   19,
#   35,
#   2086.0,
#   146000.0,
#   2,
#   70,
#   25,
#   2018,
#   'проспект',
#   'Подільський'),
#  ('Каховська',
#   4,
#   32,
#   1692.0,
#   110000.0,
#   2,
#   65,
#   25,
#   2012,
#   'вулиця',
#   'Дніпровський'),
#  ('Бойчука', 9, 0, 3166.0, 148800.0, 1, 47, 12, 2015, None, None),
#  ('Правди', 3, 36, 975.0, 77000.0, 2, 79, 25, 2018, 'проспект', 'Подільський'),
#  ('Маккейна', 5, 18, 1132.0, 38500.0, 1, 34, 9, 1977, None, None),
#  ('Перемоги',
#   16,
#   42.6,
#   1020.0,
#   100000.0,
#   3,
#   98,
#   26,
#   2012,
#   'вулиця',
#   'Святошинський'),
#  ('Перемоги',
#   16,
#   42.6,
#   1020.0,
#   100000.0,
#   3,
#   98,
#   26,
#   2012,
#   'площа',
#   'Шевченківський'),
#  ('Перемоги',
#   16,
#   42.6,
#   1020.0,
#   100000.0,
#   3,
#   98,
#   26,
#   2012,
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('Грушевського', 4, 22, 1560.0, 78000.0, 1, 50, 22, 2006, None, None),
#  ('Срібнокільська',
#   3,
#   35,
#   1071.0,
#   75000.0,
#   2,
#   70,
#   25,
#   2015,
#   'вулиця',
#   'Дарницький'),
#  ('Перемоги',
#   1,
#   30,
#   1000.0,
#   45000.0,
#   2,
#   45,
#   5,
#   1966,
#   'вулиця',
#   'Святошинський'),
#  ('Перемоги',
#   1,
#   30,
#   1000.0,
#   45000.0,
#   2,
#   45,
#   5,
#   1966,
#   'площа',
#   'Шевченківський'),
#  ('Перемоги',
#   1,
#   30,
#   1000.0,
#   45000.0,
#   2,
#   45,
#   5,
#   1966,
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('Урлівська',
#   9,
#   90,
#   6000.0,
#   900000.0,
#   3,
#   150,
#   9,
#   2019,
#   'вулиця',
#   'Дарницький'),
#  ('Заболотного', 2, 32, 1288.0, 85000.0, 2, 66, 22, 2018, None, None),
#  ('Максимовича',
#   22,
#   33,
#   1009.0,
#   65600.0,
#   2,
#   65,
#   26,
#   0,
#   'вулиця',
#   'Святошинський'),
#  ('Бажана', 11, 73, 3038.0, 395000.0, 3, 130, 28, 0, None, None),
#  ('Сікорського', 9, 0, 2214.0, 155000.0, 2, 70, 10, 2014, None, None),
#  ('Курбаса', 14, 28, 1400.0, 84000.0, 2, 60, 24, 0, None, None),
#  ('Дніпровська', 4, 37, 936.0, 73000.0, 3, 78, 4, 0, 'вулиця', 'Оболонський'),
#  ('Драгомирова', 10, 0, 1566.0, 83000.0, 1, 53, 10, 2017, None, None),
#  ('No street name', 2, 40, 3846.0, 250000.0, 2, 65, 9, 2018, None, None),
#  ('Антонова', 3, 52.3, 3425.0, 299000.0, 3, 87.3, 4, 1879, None, None),
#  ('Бучми', 9, 42, 812.0, 56000.0, 3, 69, 10, 1991, None, None),
#  ('Кубанської', 0, 0, 0.0, 117166.97297297296, 1, 61, 0, 0, None, None),
#  ('Дніпровська', 0, 0, 3333.0, 270000.0, 2, 81, 0, 0, 'вулиця', 'Оболонський'),
#  ('Панельна', 2, 30, 1018.0, 58000.0, 3, 57, 5, 1961, None, None),
#  ('Коновальця', 16, 18, 1292.0, 62000.0, 1, 48, 25, 2017, None, None),
#  ('Богатирська',
#   8,
#   14,
#   1702.0,
#   80000.0,
#   1,
#   47,
#   16,
#   0,
#   'вулиця',
#   'Оболонський'),
#  ('Оболонський',
#   2,
#   38,
#   2097.0,
#   195000.0,
#   2,
#   93,
#   6,
#   1913,
#   'проспект',
#   'Оболонський'),
#  ('Українки', 0, 0, 0.0, 85959.32432432432, 1, 49, 0, 0, None, None),
#  ('Бориса', 6, 31, 1842.0, 122000.0, 2, 66.25, 7, 0, None, None),
#  ('Правди',
#   10,
#   41,
#   52688.0,
#   102527.02702702704,
#   3,
#   72,
#   15,
#   1999,
#   'проспект',
#   'Подільський'),
#  ('Центральна',
#   1,
#   50,
#   1000.0,
#   65000.0,
#   3,
#   65,
#   5,
#   1961,
#   'вулиця',
#   'Дніпровський'),
#  ('Центральна',
#   1,
#   50,
#   1000.0,
#   65000.0,
#   3,
#   65,
#   5,
#   1961,
#   'вулиця',
#   'Оболонський'),
#  ('Центральна',
#   1,
#   50,
#   1000.0,
#   65000.0,
#   3,
#   65,
#   5,
#   1961,
#   'вулиця',
#   'Шевченківський'),
#  ('Преображенська',
#   26,
#   18,
#   827.0,
#   40500.0,
#   1,
#   49,
#   26,
#   0,
#   'вулиця',
#   "Солом'янський"),
#  ('Коновальця', 0, 0, 0.0, 31938.675675675677, 1, 31, 0, 0, None, None),
#  ('Українки', 6, 16, 1683.0, 69000.0, 1, 41, 9, 0, None, None),
#  ('No street name', 20, 0, 1415.0, 75000.0, 2, 53, 22, 0, None, None),
#  ('Велика', 12, 30, 2013.0, 155000.0, 2, 77, 21, 2013, None, None),
#  ('Липківського', 15, 39.7, 2200.0, 220000.0, 2, 100, 25, 2013, None, None),
#  ('Бойчука', 16, 24, 936.0, 51500.0, 2, 55, 25, 0, None, None),
#  ('Васильківська',
#   7,
#   32,
#   1274.0,
#   73900.0,
#   2,
#   58,
#   16,
#   1993,
#   'вулиця',
#   'Голосіївський'),
#  ('Данькевича', 0, 0, 0.0, 66441.81081081081, 1, 52, 0, 0, None, None),
#  ('Богатирська',
#   28,
#   0,
#   4487.0,
#   1400000.0,
#   5,
#   312,
#   30,
#   2016,
#   'вулиця',
#   'Оболонський'),
#  ('Українки', 16, 57, 1080.0, 93950.0, 3, 87, 17, 2018, None, None),
#  ('Гречка', 7, 80, 2724.0, 395000.0, 4, 145, 9, 0, None, None),
#  ('Редутна', 7, 15, 3580.0, 179000.0, 1, 50, 23, 2015, 'вулиця', 'Печерський'),
#  ('Бориса', 11, 64, 2080.0, 260000.0, 2, 125, 17, 2019, None, None),
#  ('Драгомирова', 6, 14, 1209.0, 52000.0, 1, 43, 25, 0, None, None),
#  ('Туполєва', 11, 73, 3038.0, 395000.0, 3, 130, 28, 0, None, None),
#  ('Кондратюка', 12, 0, 2450.0, 198450.0, 2, 81, 24, 2010, None, None),
#  ('Мінський',
#   15,
#   115,
#   3606.0,
#   750000.0,
#   3,
#   208,
#   23,
#   2005,
#   'провулок',
#   'Подільський'),
#  ('Мінський',
#   15,
#   115,
#   3606.0,
#   750000.0,
#   3,
#   208,
#   23,
#   2005,
#   'проспект',
#   'Оболонський'),
#  ('Княжий', 4, 204, 2124.0, 650000.0, 4, 306, 8, 2011, None, None),
#  ('Герцена',
#   6,
#   22,
#   1389.0,
#   75000.0,
#   1,
#   54,
#   25,
#   2007,
#   'вулиця',
#   'Шевченківський'),
#  ('Герцена',
#   6,
#   22,
#   1389.0,
#   75000.0,
#   1,
#   54,
#   25,
#   2007,
#   'провулок',
#   'Шевченківський'),
#  ('Герцена',
#   6,
#   22,
#   1389.0,
#   75000.0,
#   1,
#   54,
#   25,
#   2007,
#   'узвіз',
#   'Шевченківський'),
#  ('Балтійський',
#   4,
#   42,
#   1429.0,
#   150000.0,
#   3,
#   105,
#   24,
#   2009,
#   'провулок',
#   'Оболонський'),
#  ('Ернста', 8, 0, 1361.0, 93900.0, 2, 69, 26, 0, None, None),
#  ('Шаповала', 6, 20, 1826.0, 120500.0, 1, 66, 10, 2003, None, None),
#  ('Городецького', 5, 39, 1925.0, 129000.0, 2, 67, 25, 2014, None, None),
#  ("Сім'ї", 18, 28, 1348.0, 62000.0, 1, 46, 19, 1999, None, None),
#  ('Івана', 16, 55, 1442.0, 150000.0, 3, 104, 17, 2018, None, None),
#  ('Червоноткацька', 5, 0, 1000.0, 55000.0, 1, 55, 24, 2020, None, None),
#  ('No street name', 6, 50, 1500.0, 138000.0, 3, 92, 26, 2018, None, None),
#  ('Голосіївська',
#   7,
#   53,
#   2000.0,
#   172000.0,
#   3,
#   86,
#   9,
#   1972,
#   'вулиця',
#   'Голосіївський'),
#  ('Голосіївська',
#   7,
#   53,
#   2000.0,
#   172000.0,
#   3,
#   86,
#   9,
#   1972,
#   'площа',
#   'Голосіївський'),
#  ('No street name', 25, 50, 918.0, 79900.0, 3, 87, 26, 2018, None, None),
#  ('Миколи', 13, 18, 1157.0, 49999.0, 1, 43.2, 22, 2011, None, None),
#  ('Івана', 13, 41.89, 1326.0, 115000.0, 3, 86.74, 25, 2019, None, None),
#  ('Саперне', 2, 36.32, 958.0, 87000.0, 3, 90.77, 25, 0, None, None),
#  ('Миколи', 16, 22.3, 2202.0, 107000.0, 1, 48.6, 24, 2007, None, None),
#  ('Паторжинського',
#   19,
#   36.31,
#   1015.0,
#   87700.0,
#   2,
#   86.38,
#   24,
#   0,
#   'вулиця',
#   'Шевченківський'),
#  ('Наумовича', 9, 30, 1275.0, 65000.0, 2, 51, 9, 1978, None, None),
#  ('Калнишевського', 3, 150, 5000.0, 1250000.0, 5, 250, 4, 1858, None, None),
#  ('Дніпровська',
#   1,
#   0,
#   1388.0,
#   34700.0,
#   1,
#   25,
#   5,
#   1974,
#   'вулиця',
#   'Оболонський'),
#  ('Електриків',
#   9,
#   20,
#   1595.0,
#   67000.0,
#   1,
#   42,
#   26,
#   2017,
#   'вулиця',
#   'Подільський'),
#  ('Електриків',
#   9,
#   20,
#   1595.0,
#   67000.0,
#   1,
#   42,
#   26,
#   2017,
#   'провулок',
#   'Подільський'),
#  ("Солом'янська",
#   1,
#   20,
#   1913.0,
#   88000.0,
#   1,
#   46,
#   9,
#   0,
#   'вулиця',
#   "Солом'янський"),
#  ("Солом'янська",
#   1,
#   20,
#   1913.0,
#   88000.0,
#   1,
#   46,
#   9,
#   0,
#   'площа',
#   "Солом'янський"),
#  ('Шевченка',
#   21,
#   80.7,
#   2244.0,
#   285000.0,
#   3,
#   127,
#   25,
#   2008,
#   'вулиця',
#   'Дарницький'),
#  ('Шевченка',
#   21,
#   80.7,
#   2244.0,
#   285000.0,
#   3,
#   127,
#   25,
#   2008,
#   'вулиця',
#   'Деснянський'),
#  ('Шевченка',
#   21,
#   80.7,
#   2244.0,
#   285000.0,
#   3,
#   127,
#   25,
#   2008,
#   'вулиця',
#   "Солом'янський"),
#  ('Шевченка',
#   21,
#   80.7,
#   2244.0,
#   285000.0,
#   3,
#   127,
#   25,
#   2008,
#   'провулок',
#   'Дарницький'),
#  ('Шевченка',
#   21,
#   80.7,
#   2244.0,
#   285000.0,
#   3,
#   127,
#   25,
#   2008,
#   'провулок',
#   "Солом'янський"),
#  ('Озерна', 20, 20.9, 2022.0, 93000.0, 1, 46, 24, 0, 'вулиця', 'Дарницький'),
#  ('Озерна', 20, 20.9, 2022.0, 93000.0, 1, 46, 24, 0, 'вулиця', 'Оболонський'),
#  ('Озерна',
#   20,
#   20.9,
#   2022.0,
#   93000.0,
#   1,
#   46,
#   24,
#   0,
#   'вулиця',
#   'Святошинський (СТ "Нивки")'),
#  ('Озерна',
#   20,
#   20.9,
#   2022.0,
#   93000.0,
#   1,
#   46,
#   24,
#   0,
#   'вулиця',
#   "Солом'янський"),
#  ('Григоренка', 15, 23.8, 1288.0, 85000.0, 2, 66, 26, 0, None, None),
#  ('Антонова', 8, 60.8, 1873.0, 230000.0, 3, 122.8, 15, 2007, None, None),
#  ('Голосіївський',
#   9,
#   0,
#   2214.0,
#   155000.0,
#   2,
#   70,
#   10,
#   2014,
#   'провулок',
#   'Голосіївський'),
#  ('Голосіївський',
#   9,
#   0,
#   2214.0,
#   155000.0,
#   2,
#   70,
#   10,
#   2014,
#   'проспект',
#   'Голосіївський'),
#  ('Комарова', 8, 42, 2222.0, 180000.0, 1, 81, 32, 2016, None, None),
#  ('Борщагівська',
#   10,
#   29,
#   1730.0,
#   95000.0,
#   2,
#   54.9,
#   16,
#   1993,
#   'вулиця',
#   "Солом'янський, Шевченківський "),
#  ('Шевченка',
#   7,
#   19,
#   1330.0,
#   54934.0,
#   1,
#   41.3,
#   9,
#   1978,
#   'вулиця',
#   'Дарницький'),
#  ('Шевченка',
#   7,
#   19,
#   1330.0,
#   54934.0,
#   1,
#   41.3,
#   9,
#   1978,
#   'вулиця',
#   'Деснянський'),
#  ('Шевченка',
#   7,
#   19,
#   1330.0,
#   54934.0,
#   1,
#   41.3,
#   9,
#   1978,
#   'вулиця',
#   "Солом'янський"),
#  ('Шевченка',
#   7,
#   19,
#   1330.0,
#   54934.0,
#   1,
#   41.3,
#   9,
#   1978,
#   'провулок',
#   'Дарницький'),
#  ('Шевченка',
#   7,
#   19,
#   1330.0,
#   54934.0,
#   1,
#   41.3,
#   9,
#   1978,
#   'провулок',
#   "Солом'янський"),
#  ('Максимовича',
#   5,
#   34.4,
#   3059.0,
#   260000.0,
#   3,
#   85,
#   12,
#   0,
#   'вулиця',
#   'Святошинський'),
#  ('Ковальський',
#   10,
#   35,
#   1835.0,
#   145000.0,
#   2,
#   79,
#   25,
#   2016,
#   'провулок',
#   "Солом'янський"),
#  ('Малевича', 2, 33.5, 1627.0, 135000.0, 3, 83, 4, 1936, None, None),
#  ('Мічуріна',
#   10,
#   14.1,
#   1316.0,
#   50000.0,
#   1,
#   38,
#   18,
#   0,
#   'вулиця',
#   'Деснянський'),
#  ('Мічуріна',
#   10,
#   14.1,
#   1316.0,
#   50000.0,
#   1,
#   38,
#   18,
#   0,
#   'вулиця',
#   'Оболонський'),
#  ('Мічуріна', 10, 14.1, 1316.0, 50000.0, 1, 38, 18, 0, 'вулиця', 'Печерський'),
#  ('Мічуріна',
#   10,
#   14.1,
#   1316.0,
#   50000.0,
#   1,
#   38,
#   18,
#   0,
#   'вулиця',
#   "Солом'янський"),
#  ('Мічуріна',
#   10,
#   14.1,
#   1316.0,
#   50000.0,
#   1,
#   38,
#   18,
#   0,
#   'провулок',
#   'Печерський'),
#  ('No street name', 3, 98, 2494.0, 399000.0, 3, 160, 9, 2005, None, None),
#  ('Балтійський',
#   4,
#   19,
#   1486.0,
#   55000.0,
#   1,
#   37,
#   5,
#   1959,
#   'провулок',
#   'Оболонський'),
#  ('Азербайджанська',
#   7,
#   137,
#   1362.0,
#   270000.0,
#   5,
#   198.3,
#   16,
#   2001,
#   'вулиця',
#   'Дніпровський'),
#  ('Зарічна',
#   12,
#   0,
#   3120.0,
#   337000.0,
#   3,
#   108,
#   27,
#   2015,
#   'вулиця',
#   'Дарницький'),
#  ('Чавдар', 16, 106.5, 1133.0, 170000.0, 4, 150, 17, 1988, None, None),
#  ('Правди', 4, 0, 1181.0, 85000.0, 3, 72, 9, 1981, 'проспект', 'Подільський'),
#  ('Урлівська',
#   5,
#   97.3,
#   2131.0,
#   279000.0,
#   4,
#   130.9,
#   5,
#   1936,
#   'вулиця',
#   'Дарницький'),
#  ('Бориспільська',
#   8,
#   14,
#   1073.0,
#   44000.0,
#   1,
#   41,
#   26,
#   2019,
#   'вулиця',
#   'Дарницький'),
#  ('Поправки', 4, 44, 3208.0, 170000.0, 1, 53, 26, 2005, None, None),
#  ('Бориспільська',
#   3,
#   16,
#   2047.0,
#   88000.0,
#   1,
#   43,
#   24,
#   0,
#   'вулиця',
#   'Дарницький'),
#  ('Ентузіастів',
#   3,
#   29,
#   892.0,
#   41500.0,
#   2,
#   46.5,
#   5,
#   1965,
#   'вулиця',
#   'Дніпровський'),
#  ('Малоземельна',
#   11,
#   34,
#   986.0,
#   70000.0,
#   2,
#   71,
#   25,
#   2018,
#   'вулиця',
#   'Дарницький'),
#  ('Саксаганського',
#   18,
#   29.25,
#   2141.0,
#   119900.0,
#   2,
#   56,
#   24,
#   0,
#   'вулиця',
#   'Голосіївський, Печерський, Шевченківський'),
#  ('Героїв', 12, 62.2, 729.0, 86000.0, 3, 118, 23, 2010, None, None),
#  ('Зодчих',
#   25,
#   40,
#   1725.0,
#   138000.0,
#   3,
#   80,
#   26,
#   2014,
#   'вулиця',
#   'Святошинський'),
#  ('Калнишевського', 4, 38, 2824.0, 240000.0, 2, 85, 8, 2016, None, None),
#  ('Філатова', 11, 56, 1438.0, 149500.0, 3, 104, 16, 2002, None, None),
#  ('Старонаводницька',
#   1,
#   29.73,
#   33177.0,
#   54043.24324324324,
#   1,
#   60.27,
#   4,
#   0,
#   'вулиця',
#   'Печерський'),
#  ('Заболотного', 8, 30, 1438.0, 67999.0, 2, 47.3, 9, 0, None, None),
#  ('Правди', 2, 16, 1339.0, 41500.0, 1, 31, 5, 1963, 'проспект', 'Подільський'),
#  ('No street name', 10, 47, 1100.0, 99000.0, 3, 90, 10, 2005, None, None),
#  ('Антоновича',
#   18,
#   65,
#   5577.0,
#   580000.0,
#   3,
#   104,
#   26,
#   2016,
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('Шаповала', 7, 17, 1630.0, 75000.0, 1, 46, 19, 2018, None, None),
#  ('Івана', 4, 48, 2903.0, 299000.0, 3, 103, 24, 2015, None, None),
#  ('Деревлянська',
#   13,
#   0,
#   1158.0,
#   44000.0,
#   1,
#   38,
#   16,
#   1985,
#   'вулиця',
#   'Шевченківський'),
#  ('Вільямса', 23, 66, 1252.0, 139000.0, 3, 111, 36, 2007, None, None),
#  ('Васильченка',
#   26,
#   37.2,
#   1667.0,
#   150000.0,
#   3,
#   90,
#   26,
#   2010,
#   'вулиця',
#   "Солом'янський"),
#  ('Предславинська',
#   9,
#   26.5,
#   819.0,
#   45690.0,
#   2,
#   55.8,
#   16,
#   0,
#   'вулиця',
#   'Печерський'),
#  ('Крайня',
#   13,
#   35,
#   1456.0,
#   115000.0,
#   2,
#   79,
#   17,
#   2014,
#   'вулиця',
#   'Деснянський'),
#  ('Милославська', 8, 0, 858.0, 63500.0, 3, 74, 10, 0, 'вулиця', 'Деснянський'),
#  ('Воскресенська',
#   9,
#   0,
#   913.0,
#   42000.0,
#   2,
#   46,
#   9,
#   1970,
#   'вулиця',
#   'Дніпровський'),
#  ('Маланюка', 1, 29.5, 1153.0, 56500.0, 2, 49, 9, 1975, None, None),
#  ('Дніпровська',
#   1,
#   36,
#   868.0,
#   66000.0,
#   2,
#   76,
#   25,
#   2014,
#   'вулиця',
#   'Оболонський'),
#  ('Пушкінська',
#   21,
#   61,
#   1000.0,
#   103000.0,
#   3,
#   103,
#   22,
#   2012,
#   'вулиця',
#   'Шевченківський'),
#  ('Набережно-Корчуватська',
#   13,
#   15.5,
#   1355.0,
#   63000.0,
#   1,
#   46.5,
#   26,
#   2019,
#   'вулиця',
#   'Голосіївський'),
#  ('Зарічна', 8, 0, 2073.0, 228000.0, 3, 110, 10, 0, 'вулиця', 'Дарницький'),
#  ('Тургенєвська',
#   5,
#   46,
#   1286.0,
#   90000.0,
#   3,
#   70,
#   16,
#   1974,
#   'вулиця',
#   'Шевченківський'),
#  ('Радченка', 9, 52, 915.0, 87000.0, 3, 95.09, 19, 2019, None, None),
#  ('Зарічна', 1, 41, 1033.0, 62000.0, 3, 60, 9, 1975, 'вулиця', 'Дарницький'),
#  ('Метрологічна',
#   4,
#   46,
#   828.0,
#   77000.0,
#   3,
#   93,
#   16,
#   2002,
#   'вулиця',
#   'Голосіївський'),
#  ('Йорданська',
#   12,
#   68,
#   1384.0,
#   179900.0,
#   3,
#   130,
#   16,
#   1998,
#   'вулиця',
#   'Оболонський'),
#  ('Кольцова',
#   2,
#   15,
#   1960.0,
#   49000.0,
#   1,
#   25,
#   4,
#   2016,
#   'бульвар',
#   'Святошинський'),
#  ('Максимовича',
#   22,
#   0,
#   1925.0,
#   105900.0,
#   1,
#   55,
#   26,
#   2016,
#   'вулиця',
#   'Святошинський'),
#  ('Науки',
#   3,
#   101,
#   2924.0,
#   500000.0,
#   3,
#   171,
#   8,
#   2012,
#   'проспект',
#   'Голосіївський'),
#  ('Саперно-Слобідська',
#   15,
#   15.4,
#   884.0,
#   38000.0,
#   1,
#   43,
#   25,
#   0,
#   'вулиця',
#   'Голосіївський'),
#  ('Шовковична',
#   16,
#   18,
#   2708.0,
#   130000.0,
#   1,
#   48,
#   24,
#   2008,
#   'вулиця',
#   'Печерський'),
#  ('Трускавецька',
#   4,
#   0,
#   2644.0,
#   230000.0,
#   3,
#   87,
#   9,
#   2013,
#   'вулиця',
#   'Дарницький'),
#  ('Гавела', 4, 34, 1260.0, 66800.0, 2, 53, 9, 1969, None, None),
#  ('Повітрофлотський',
#   2,
#   54,
#   1488.0,
#   125000.0,
#   2,
#   84,
#   12,
#   2020,
#   'проспект',
#   "Шевченківський, Солом'янський"),
#  ('Запорожця', 2, 27, 2457.0, 113000.0, 2, 46, 5, 1913, None, None),
#  ('Маккейна', 10, 0, 1788.0, 93000.0, 1, 52, 15, 2017, None, None),
#  ('Перемоги',
#   13,
#   68,
#   4637.0,
#   422000.0,
#   2,
#   91,
#   15,
#   2017,
#   'вулиця',
#   'Святошинський'),
#  ('Перемоги',
#   13,
#   68,
#   4637.0,
#   422000.0,
#   2,
#   91,
#   15,
#   2017,
#   'площа',
#   'Шевченківський'),
#  ('Перемоги',
#   13,
#   68,
#   4637.0,
#   422000.0,
#   2,
#   91,
#   15,
#   2017,
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('Щербаківського', 26, 34, 1238.0, 80500.0, 2, 65, 13, 2020, None, None),
#  ('Зарічна', 6, 0, 1500.0, 123000.0, 2, 82, 26, 0, 'вулиця', 'Дарницький'),
#  ('Будищанська',
#   3,
#   60,
#   2273.0,
#   200000.0,
#   3,
#   88,
#   7,
#   1954,
#   'вулиця',
#   'Деснянський'),
#  ('Жилянська',
#   5,
#   25,
#   1268.0,
#   52000.0,
#   2,
#   41,
#   5,
#   0,
#   'вулиця',
#   'Печерський, Голосіївський, Шевченківський'),
#  ('Комбінатна',
#   5,
#   120,
#   2400.0,
#   360000.0,
#   5,
#   150,
#   6,
#   1936,
#   'вулиця',
#   'Дніпровський'),
#  ('Ревуцького',
#   23,
#   35,
#   1397.0,
#   102000.0,
#   2,
#   73,
#   25,
#   2016,
#   'вулиця',
#   'Дарницький'),
#  ('Бородіна', 18, 0, 951.0, 77000.0, 3, 81, 26, 2018, None, None),
#  ('Руставелі', 6, 15, 2500.0, 125000.0, 1, 50, 25, 0, None, None),
#  ('Драгоманова',
#   10,
#   0,
#   2270.0,
#   84000.0,
#   1,
#   37,
#   16,
#   2019,
#   'вулиця',
#   'Дарницький'),
#  ('Преображенська',
#   3,
#   0,
#   3083.0,
#   185000.0,
#   1,
#   60,
#   30,
#   2014,
#   'вулиця',
#   "Солом'янський"),
#  ('Депутатська',
#   0,
#   0,
#   0.0,
#   24005.108108108107,
#   1,
#   30,
#   0,
#   0,
#   'вулиця',
#   'Святошинський'),
#  ('Багговутівська',
#   8,
#   31,
#   717.0,
#   45142.0,
#   2,
#   63,
#   19,
#   0,
#   'вулиця',
#   'Шевченківський'),
#  ('No street name', 10, 150, 4601.0, 980000.0, 5, 213, 13, 2003, None, None),
#  ('Сікорського', 6, 41, 2442.0, 180000.0, 2, 73.7, 17, 2009, None, None),
#  ('Драгомирова', 2, 28.8, 887.0, 40000.0, 2, 45.1, 5, 1964, None, None),
#  ('Коперніка',
#   2,
#   54,
#   1264.0,
#   110000.0,
#   4,
#   87,
#   16,
#   1986,
#   'вулиця',
#   'Шевченківський'),
#  ('Васильківська',
#   0,
#   0,
#   0.0,
#   97319.02702702704,
#   2,
#   68,
#   0,
#   0,
#   'вулиця',
#   'Голосіївський'),
#  ('Глибочицька',
#   9,
#   60,
#   1602.0,
#   165000.0,
#   3,
#   103,
#   17,
#   2011,
#   'вулиця',
#   'Шевченківський'),
#  ('Чавдар', 23, 34.01, 1157.0, 92550.0, 2, 79.97, 26, 0, None, None),
#  ('Шовковична',
#   25,
#   53.47,
#   879.0,
#   80000.0,
#   4,
#   91,
#   26,
#   0,
#   'вулиця',
#   'Печерський'),
#  ('Дніпровська',
#   24,
#   0,
#   1797.0,
#   115000.0,
#   2,
#   64,
#   25,
#   2018,
#   'вулиця',
#   'Оболонський'),
#  ('Антоновича',
#   0,
#   0,
#   0.0,
#   117166.97297297296,
#   1,
#   61,
#   0,
#   0,
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('No street name', 7, 36, 1649.0, 155000.0, 2, 94, 25, 0, None, None),
#  ('Славгородська',
#   4,
#   0,
#   1982.0,
#   220000.0,
#   3,
#   111,
#   17,
#   2010,
#   'вулиця',
#   'Дарницький'),
#  ('Драгомирова', 3, 0, 2065.0, 95000.0, 2, 46, 24, 2017, None, None),
# ...
#  ('Володимирська',
#   4,
#   43.2,
#   2068.0,
#   170000.0,
#   3,
#   82.2,
#   5,
#   1910,
#   'вулиця',
#   'Голосіївський, Шевченківський'),
#  ('Українки', 22, 23, 2683.0, 110000.0, 1, 41, 25, 0, None, None),
#  ('Сім’ї', 3, 28, 1405.0, 59000.0, 2, 42, 9, 1967, None, None),
#  ('Коновальця', 1, 41, 2377.0, 145000.0, 3, 61, 9, 1972, None, None),
#  ('Мирного', 28, 30, 988.0, 79000.0, 2, 80, 28, 2010, None, None),
#  ('Московська', 0, 0, 3151.0, 375000.0, 3, 119, 0, 0, 'вулиця', 'Печерський'),
#  ('Московська',
#   0,
#   0,
#   3151.0,
#   375000.0,
#   3,
#   119,
#   0,
#   0,
#   'вулиця',
#   "Солом'янський"),
#  ('Жмеринська',
#   5,
#   0,
#   2302.0,
#   122000.0,
#   1,
#   53,
#   12,
#   2013,
#   'вулиця',
#   'Святошинський'),
#  ('Бойчука', 12, 0, 4048.0, 255000.0, 2, 63, 19, 2013, None, None),
#  ('Липківського', 5, 0, 1977.0, 85000.0, 2, 43, 5, 1961, None, None),
#  ('Лабораторний',
#   8,
#   43,
#   2800.0,
#   240800.0,
#   2,
#   86,
#   27,
#   2017,
#   'провулок',
#   'Печерський'),
#  ('Інститутська',
#   0,
#   0,
#   3792.0,
#   455000.0,
#   3,
#   120,
#   0,
#   0,
#   'вулиця',
#   'Печерський'),
#  ('Українки', 7, 56, 1528.0, 165000.0, 3, 108, 10, 2005, None, None),
#  ('Хрещатик',
#   3,
#   57,
#   1064.0,
#   100000.0,
#   3,
#   94,
#   25,
#   2017,
#   'вулиця',
#   'Печерський, Шевченківський'),
#  ('Дніпровська',
#   20,
#   51.7,
#   1696.0,
#   195000.0,
#   3,
#   115,
#   24,
#   2007,
#   'вулиця',
#   'Оболонський'),
#  ('Осокорська',
#   14,
#   15,
#   1131.0,
#   41000.0,
#   1,
#   36.25,
#   26,
#   0,
#   'вулиця',
#   'Дарницький'),
#  ('Саперне', 2, 26.7, 1273.0, 70000.0, 2, 55, 3, 1955, None, None),
#  ('Комарова', 13, 34, 1152.0, 71400.0, 2, 62, 26, 2020, None, None),
#  ('Драгомирова', 0, 0, 0.0, 100320.67567567568, 1, 53, 0, 0, None, None),
#  ('Срібнокільська',
#   3,
#   33.2,
#   1237.0,
#   60000.0,
#   3,
#   48.5,
#   3,
#   0,
#   'вулиця',
#   'Дарницький'),
#  ('Чоколівський',
#   22,
#   62,
#   1967.0,
#   240000.0,
#   3,
#   122,
#   30,
#   2013,
#   'бульвар',
#   "Солом'янський"),
#  ('Звіринецька',
#   4,
#   53,
#   2889.0,
#   260000.0,
#   3,
#   90,
#   14,
#   2013,
#   'вулиця',
#   'Печерський'),
#  ('Вишгородська',
#   7,
#   33,
#   2309.0,
#   127000.0,
#   2,
#   55,
#   9,
#   1977,
#   'вулиця',
#   'Подільський, Оболонський'),
#  ('Драгомирова', 11, 15, 1000.0, 40000.0, 1, 40, 16, 0, None, None),
#  ('Героїв', 0, 0, 0.0, 48552.40540540541, 1, 46, 0, 0, None, None),
#  ('Будівельників',
#   0,
#   0,
#   10000.0,
#   3400000.0,
#   5,
#   340,
#   0,
#   0,
#   'вулиця',
#   'Деснянський'),
#  ('Будівельників',
#   0,
#   0,
#   10000.0,
#   3400000.0,
#   5,
#   340,
#   0,
#   0,
#   'вулиця',
#   'Дніпровський'),
#  ('Будівельників',
#   0,
#   0,
#   10000.0,
#   3400000.0,
#   5,
#   340,
#   0,
#   0,
#   'провулок',
#   'Дніпровський'),
#  ('Будівельників',
#   0,
#   0,
#   10000.0,
#   3400000.0,
#   5,
#   340,
#   0,
#   0,
#   'провулок',
#   'Святошинський'),
#  ('Іллєнка', 2, 16, 1085.0, 44500.0, 1, 41, 25, 0, None, None),
#  ('Урлівська',
#   3,
#   27,
#   2660.0,
#   125000.0,
#   2,
#   47,
#   5,
#   1954,
#   'вулиця',
#   'Дарницький'),
#  ('Сормовська', 9, 35, 927.0, 51000.0, 3, 55, 9, 1972, 'вулиця', 'Дарницький'),
#  ('Правди',
#   0,
#   0,
#   0.0,
#   46156.48648648649,
#   2,
#   79,
#   0,
#   0,
#   'проспект',
#   'Подільський'),
#  ('Верховинна',
#   7,
#   34.21,
#   1000.0,
#   65000.0,
#   2,
#   65,
#   20,
#   2018,
#   'вулиця',
#   'Святошинський'),
#  ('Вербицького', 17, 0, 1719.0, 55000.0, 1, 32, 25, 2018, None, None),
#  ('No street name', 1, 36, 1500.0, 94500.0, 2, 63, 8, 1957, None, None),
#  ('Велика', 15, 25, 2300.0, 115000.0, 1, 50, 25, 2009, None, None),
#  ('Бойчука', 11, 12, 1250.0, 45000.0, 1, 36, 26, 0, None, None),
#  ('Лобановського', 9, 30, 2429.0, 85000.0, 1, 35, 9, 2019, None, None),
#  ('Миколи', 0, 0, 0.0, 140668.9189189189, 1, 52, 0, 0, None, None),
#  ('Кропивницького',
#   21,
#   15,
#   1690.0,
#   84500.0,
#   1,
#   50,
#   25,
#   0,
#   'вулиця',
#   'Печерський'),
#  ('Трускавецька',
#   7,
#   90,
#   2121.0,
#   350000.0,
#   3,
#   165,
#   15,
#   2005,
#   'вулиця',
#   'Дарницький'),
#  ('Голосіївська',
#   28,
#   40,
#   2563.0,
#   182000.0,
#   2,
#   71,
#   34,
#   2018,
#   'вулиця',
#   'Голосіївський'),
#  ('Голосіївська',
#   28,
#   40,
#   2563.0,
#   182000.0,
#   2,
#   71,
#   34,
#   2018,
#   'площа',
#   'Голосіївський'),
#  ('Маланюка', 4, 61, 1718.0, 188999.0, 3, 110, 19, 2017, None, None),
#  ('Драгомирова', 4, 19.2, 1441.0, 147000.0, 3, 102, 8, 2011, None, None),
#  ('Юнацька', 24, 35, 1124.0, 89900.0, 3, 80, 25, 0, 'вулиця', 'Святошинський'),
#  ('Юнацька', 24, 35, 1124.0, 89900.0, 3, 80, 25, 0, 'вулиця', "Солом'янський"),
#  ('Максимовича',
#   5,
#   39,
#   1115.0,
#   66900.0,
#   3,
#   60,
#   9,
#   1977,
#   'вулиця',
#   'Святошинський'),
#  ('Комарова', 3, 35, 1071.0, 75000.0, 2, 70, 25, 2015, None, None),
#  ('Багговутівська',
#   1,
#   54,
#   725.0,
#   58000.0,
#   4,
#   80,
#   9,
#   1987,
#   'вулиця',
#   'Шевченківський'),
#  ('No street name', 7, 50, 1667.0, 140000.0, 3, 84, 10, 0, None, None),
#  ('Костанайська',
#   10,
#   41.9,
#   1139.0,
#   82000.0,
#   3,
#   72,
#   16,
#   1995,
#   'вулиця',
#   'Голосіївський'),
#  ('Срібнокільська',
#   10,
#   42,
#   2240.0,
#   215000.0,
#   2,
#   96,
#   25,
#   2005,
#   'вулиця',
#   'Дарницький'),
#  ('Курчатова', 1, 18, 1044.0, 33400.0, 1, 32, 5, 1961, None, None),
#  ('Гусовського',
#   4,
#   43,
#   885.0,
#   100000.0,
#   4,
#   113,
#   14,
#   2000,
#   'вулиця',
#   'Печерський'),
#  ('Українки', 5, 0, 2017.0, 240000.0, 3, 119, 25, 2008, None, None),
#  ('Драгоманова',
#   23,
#   26,
#   1016.0,
#   62000.0,
#   2,
#   61,
#   25,
#   2018,
#   'вулиця',
#   'Дарницький'),
#  ('Дніпровська',
#   18,
#   34,
#   1533.0,
#   115000.0,
#   2,
#   75,
#   25,
#   2014,
#   'вулиця',
#   'Оболонський'),
#  ('Заболотного', 9, 16.75, 2618.0, 143560.0, 1, 54.83, 30, 0, None, None),
#  ('Заболотного', 4, 54, 1585.0, 130000.0, 3, 82, 6, 0, None, None),
#  ('Перемоги',
#   7,
#   56,
#   1551.0,
#   152000.0,
#   3,
#   98,
#   20,
#   2010,
#   'вулиця',
#   'Святошинський'),
#  ('Перемоги',
#   7,
#   56,
#   1551.0,
#   152000.0,
#   3,
#   98,
#   20,
#   2010,
#   'площа',
#   'Шевченківський'),
#  ('Перемоги',
#   7,
#   56,
#   1551.0,
#   152000.0,
#   3,
#   98,
#   20,
#   2010,
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('Сверстюка', 3, 21, 1056.0, 33800.0, 1, 32, 5, 1966, None, None),
#  ('Липківського', 2, 15.3, 1486.0, 55000.0, 1, 37, 25, 0, None, None),
#  ('Маккейна', 16, 51.9, 1146.0, 110000.0, 3, 96, 22, 2005, None, None),
#  ('Дніпровська',
#   12,
#   39,
#   2703.0,
#   200000.0,
#   2,
#   74,
#   14,
#   2015,
#   'вулиця',
#   'Оболонський'),
#  ('Волгоградська',
#   4,
#   24,
#   1296.0,
#   70000.0,
#   2,
#   54,
#   26,
#   0,
#   'вулиця',
#   "Солом'янський"),
#  ('Волгоградська',
#   4,
#   24,
#   1296.0,
#   70000.0,
#   2,
#   54,
#   26,
#   0,
#   'площа',
#   'Деснянський'),
#  ('Новопольова',
#   5,
#   39,
#   1828.0,
#   160888.0,
#   3,
#   88,
#   5,
#   1962,
#   'вулиця',
#   "Солом'янський"),
#  ('Драгоманова',
#   3,
#   55,
#   1510.0,
#   189000.0,
#   3,
#   125.2,
#   18,
#   2015,
#   'вулиця',
#   'Дарницький'),
#  ('Лебедєва', 16, 25, 2077.0, 135000.0, 2, 65, 23, 2012, None, None),
#  ('No street name', 3, 26, 4300.0, 215000.0, 2, 50, 3, 1903, None, None),
#  ('Драгомирова', 10, 57, 1020.0, 102000.0, 3, 100, 10, 1998, None, None),
#  ('Лейпцизька',
#   22,
#   75,
#   1550.0,
#   193750.0,
#   3,
#   125,
#   22,
#   2016,
#   'вулиця',
#   'Печерський'),
#  ('Глибочицька',
#   10,
#   18,
#   982.0,
#   54000.0,
#   1,
#   55,
#   25,
#   2020,
#   'вулиця',
#   'Шевченківський'),
#  ('Салютна',
#   4,
#   39,
#   1273.0,
#   70000.0,
#   2,
#   55,
#   5,
#   1938,
#   'вулиця',
#   'Шевченківський'),
#  ('Метрологічна',
#   0,
#   0,
#   0.0,
#   85959.32432432432,
#   1,
#   49,
#   0,
#   0,
#   'вулиця',
#   'Голосіївський'),
#  ('Північно-Сирецька',
#   18,
#   18,
#   973.0,
#   50500.0,
#   1,
#   51.89,
#   25,
#   0,
#   'вулиця',
#   'Подільський'),
#  ('Правди', 1, 44, 1036.0, 57000.0, 3, 55, 5, 1966, 'проспект', 'Подільський'),
#  ('Вернадського', 1, 37.3, 2152.0, 130000.0, 2, 60.4, 5, 1937, None, None),
#  ('Пчілки', 6, 70, 2015.0, 262000.0, 3, 130, 17, 2019, None, None),
#  ('Лейпцизька',
#   12,
#   18,
#   1650.0,
#   66000.0,
#   1,
#   40,
#   16,
#   2019,
#   'вулиця',
#   'Печерський'),
#  ('Басейна',
#   0,
#   0,
#   0.0,
#   87812.32432432432,
#   1,
#   56,
#   0,
#   0,
#   'вулиця',
#   'Печерський, Шевченківський'),
#  ('Шаповала', 8, 37, 26667.0, 54054.05405405405, 2, 75, 26, 2019, None, None),
#  ('Бережанська',
#   2,
#   64,
#   796.0,
#   78000.0,
#   4,
#   98,
#   9,
#   1985,
#   'вулиця',
#   'Оболонський'),
#  ('Бойчука', 17, 20, 1550.0, 90500.0, 1, 58.4, 21, 0, None, None),
#  ('Перемоги',
#   6,
#   30,
#   1569.0,
#   80000.0,
#   2,
#   51,
#   9,
#   1981,
#   'вулиця',
#   'Святошинський'),
#  ('Перемоги',
#   6,
#   30,
#   1569.0,
#   80000.0,
#   2,
#   51,
#   9,
#   1981,
#   'площа',
#   'Шевченківський'),
#  ('Перемоги',
#   6,
#   30,
#   1569.0,
#   80000.0,
#   2,
#   51,
#   9,
#   1981,
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('Івана', 0, 0, 0.0, 24488.64864864865, 1, 32, 0, 0, None, None),
#  ('Антоновича',
#   18,
#   0,
#   14610.0,
#   4500000.0,
#   4,
#   308,
#   21,
#   2011,
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('Вільямса', 4, 15, 1067.0, 32000.0, 1, 30, 25, 0, None, None),
#  ('Бойчука', 14, 0, 2111.0, 190000.0, 2, 90, 16, 1983, None, None),
#  ('Перемоги', 2, 30, 3607.0, 220000.0, 3, 61, 5, 0, 'вулиця', 'Святошинський'),
#  ('Перемоги', 2, 30, 3607.0, 220000.0, 3, 61, 5, 0, 'площа', 'Шевченківський'),
#  ('Перемоги',
#   2,
#   30,
#   3607.0,
#   220000.0,
#   3,
#   61,
#   5,
#   0,
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('Ковпака',
#   9,
#   49,
#   1048.0,
#   110000.0,
#   3,
#   105,
#   26,
#   0,
#   'вулиця',
#   'Голосіївський, Печерський'),
#  ('Русанівський',
#   3,
#   18,
#   1344.0,
#   43000.0,
#   1,
#   32,
#   26,
#   2018,
#   'бульвар',
#   'Дніпровський'),
#  ('Українки', 0, 0, 0.0, 26574.405405405407, 1, 27, 0, 0, None, None),
#  ('Празька',
#   5,
#   16,
#   1757.0,
#   65000.0,
#   1,
#   37,
#   27,
#   2019,
#   'вулиця',
#   'Дніпровський'),
#  ('Гончара', 15, 48, 1447.0, 110000.0, 2, 76, 16, 2004, None, None),
#  ('Маккейна', 24, 44, 2000.0, 150000.0, 3, 75, 25, 2014, None, None),
#  ('Балтійський',
#   4,
#   30,
#   1931.0,
#   125500.0,
#   2,
#   65,
#   16,
#   2017,
#   'провулок',
#   'Оболонський'),
#  ('Білоруська',
#   2,
#   60,
#   1754.0,
#   200000.0,
#   3,
#   114,
#   10,
#   2000,
#   'вулиця',
#   'Шевченківський'),
#  ('Драгоманова',
#   9,
#   0,
#   3158.0,
#   480000.0,
#   1,
#   152,
#   21,
#   2004,
#   'вулиця',
#   'Дарницький'),
#  ('Липківського', 14, 60, 2043.0, 235000.0, 4, 115, 24, 2012, None, None),
#  ('Новогоспітальна',
#   12,
#   44,
#   921.0,
#   82000.0,
#   2,
#   89,
#   27,
#   0,
#   'вулиця',
#   'Печерський'),
#  ('Радченка', 3, 35, 1742.0, 121975.0, 2, 70, 22, 2019, None, None),
#  ('Богомольця', 9, 60.1, 2375.0, 200000.0, 2, 84.2, 26, 2017, None, None),
#  ('Донця', 9, 125, 1586.0, 250000.0, 4, 157.6, 17, 2001, None, None),
#  ('Оболонський',
#   3,
#   52,
#   2412.0,
#   205000.0,
#   2,
#   85,
#   7,
#   1948,
#   'проспект',
#   'Оболонський'),
#  ('Щекавицька', 9, 37, 921.0, 76466.0, 2, 83, 13, 0, 'вулиця', 'Подільський'),
#  ('Щекавицька', 9, 37, 921.0, 76466.0, 2, 83, 13, 0, 'площа', 'Подільський'),
#  ('Пожарського',
#   22,
#   0,
#   2017.0,
#   240000.0,
#   3,
#   119,
#   30,
#   2013,
#   'вулиця',
#   'Деснянський'),
#  ('Пожарського',
#   22,
#   0,
#   2017.0,
#   240000.0,
#   3,
#   119,
#   30,
#   2013,
#   'вулиця',
#   'Дніпровський'),
#  ('Полкова',
#   25,
#   52,
#   1500.0,
#   150000.0,
#   2,
#   100,
#   26,
#   2018,
#   'вулиця',
#   'Подільський'),
#  ('Донця', 9, 15.6, 1643.0, 69000.0, 1, 42, 9, 2018, None, None),
#  ('Палладіна', 3, 15, 1702.0, 74900.0, 1, 44, 17, 2017, None, None),
#  ('Бойчука', 17, 50, 5153.0, 1350000.0, 4, 262, 17, 2010, None, None),
#  ('Липківського', 0, 0, 3088.0, 386000.0, 4, 125, 0, 0, None, None),
#  ('Павлівська',
#   21,
#   0,
#   900.0,
#   31500.0,
#   1,
#   35,
#   25,
#   0,
#   'вулиця',
#   'Шевченківський'),
#  ('Івашкевича', 2, 30, 1137.0, 58000.0, 2, 51, 10, 1987, None, None),
#  ('Іскрівська',
#   15,
#   30,
#   1742.0,
#   115000.0,
#   2,
#   66,
#   25,
#   2018,
#   'вулиця',
#   "Солом'янський"),
#  ('Максимовича',
#   1,
#   41.1,
#   956.0,
#   64999.0,
#   3,
#   68,
#   9,
#   1973,
#   'вулиця',
#   'Святошинський'),
#  ('No street name', 6, 46.2, 999.0, 69900.0, 3, 70, 9, 1969, None, None),
#  ('Драгомирова', 18, 59, 1947.0, 220000.0, 3, 113, 27, 2015, None, None),
#  ('Теремківська',
#   22,
#   27.6,
#   43400.0,
#   77650.81081081081,
#   2,
#   66.2,
#   22,
#   2016,
#   'вулиця',
#   'Голосіївський'),
#  ('Осокорська',
#   19,
#   34,
#   1722.0,
#   186000.0,
#   2,
#   108,
#   25,
#   2014,
#   'вулиця',
#   'Дарницький'),
#  ('Дмитрівська',
#   24,
#   14,
#   935.0,
#   43000.0,
#   1,
#   46,
#   26,
#   0,
#   'вулиця',
#   'Подільський'),
#  ('Дмитрівська',
#   24,
#   14,
#   935.0,
#   43000.0,
#   1,
#   46,
#   26,
#   0,
#   'вулиця',
#   'Шевченківський'),
#  ('Кондратюка', 5, 42, 917.0, 55000.0, 3, 60, 5, 1965, None, None),
#  ('Регенераторна',
#   22,
#   75,
#   1550.0,
#   193750.0,
#   3,
#   125,
#   22,
#   2016,
#   'вулиця',
#   'Дніпровський'),
#  ('No street name', 3, 16.3, 1741.0, 100999.0, 1, 58, 15, 2004, None, None),
#  ('Глибочицька',
#   25,
#   0,
#   55506.0,
#   297782.1891891892,
#   5,
#   198.5,
#   26,
#   0,
#   'вулиця',
#   'Шевченківський'),
#  ('Героїв', 12, 0, 1242.0, 149000.0, 3, 120, 14, 2011, None, None),
#  ('Борщагівська',
#   0,
#   0,
#   0.0,
#   97319.02702702704,
#   2,
#   68,
#   0,
#   0,
#   'вулиця',
#   "Солом'янський, Шевченківський "),
#  ('Ревуцького',
#   21,
#   15.5,
#   1071.0,
#   45000.0,
#   1,
#   42,
#   25,
#   0,
#   'вулиця',
#   'Дарницький'),
#  ('Юнацька',
#   19,
#   31,
#   1333.0,
#   92000.0,
#   2,
#   69,
#   25,
#   2019,
#   'вулиця',
#   'Святошинський'),
#  ('Юнацька',
#   19,
#   31,
#   1333.0,
#   92000.0,
#   2,
#   69,
#   25,
#   2019,
#   'вулиця',
#   "Солом'янський"),
#  ('Заболотного', 21, 55, 3430.0, 295000.0, 2, 86, 25, 2019, None, None),
#  ('Автозаводська',
#   8,
#   0,
#   1247.0,
#   39900.0,
#   1,
#   32,
#   26,
#   0,
#   'вулиця',
#   'Оболонський'),
#  ('Заболотного', 17, 88.5, 1490.0, 215000.0, 4, 144.3, 24, 2008, None, None),
#  ('Саксаганського',
#   0,
#   0,
#   0.0,
#   66441.81081081081,
#   1,
#   52,
#   0,
#   0,
#   'вулиця',
#   'Голосіївський, Печерський, Шевченківський'),
#  ('Зарічна',
#   6,
#   43.6,
#   1500.0,
#   138000.0,
#   3,
#   92,
#   25,
#   2018,
#   'вулиця',
#   'Дарницький'),
#  ('No street name', 20, 30, 833.0, 50000.0, 2, 60, 25, 2016, None, None),
#  ('Невська', 8, 32.32, 1138.0, 92284.0, 2, 81.09, 34, 0, None, None),
#  ('Героїв', 12, 122.2, 741.0, 140000.0, 6, 189, 13, 2006, None, None),
#  ('Вишняківська',
#   0,
#   0,
#   0.0,
#   100199.4054054054,
#   1,
#   59,
#   0,
#   0,
#   'вулиця',
#   'Дарницький'),
#  ('Драгомирова', 8, 25, 1362.0, 94000.0, 2, 69, 26, 2019, None, None),
#  ('Драгомирова', 15, 18, 938.0, 45000.0, 1, 48, 25, 0, None, None),
#  ('Гавела', 1, 0, 903.0, 56000.0, 3, 62, 5, 1963, None, None),
#  ('Здолбунівська',
#   18,
#   0,
#   1609.0,
#   140000.0,
#   3,
#   87,
#   25,
#   2014,
#   'вулиця',
#   'Дарницький'),
#  ('Драгомирова', 15, 40, 1084.0, 90000.0, 3, 83, 23, 2017, None, None),
#  ('Мечнікова',
#   2,
#   33,
#   2446.0,
#   159000.0,
#   2,
#   65,
#   4,
#   1911,
#   'вулиця',
#   'Печерський'),
#  ('No street name', 0, 0, 0.0, 49958.10810810811, 1, 37, 0, 0, None, None),
#  ('Максимовича',
#   2,
#   24,
#   1893.0,
#   106000.0,
#   2,
#   56,
#   9,
#   0,
#   'вулиця',
#   'Святошинський'),
#  ('Багговутівська',
#   3,
#   43,
#   2656.0,
#   170000.0,
#   2,
#   64,
#   9,
#   1969,
#   'вулиця',
#   'Шевченківський'),
#  ('Шолуденка',
#   24,
#   41,
#   1167.0,
#   91000.0,
#   3,
#   78,
#   25,
#   0,
#   'вулиця',
#   'Шевченківський'),
#  ('Щекавицька',
#   5,
#   43,
#   1719.0,
#   110000.0,
#   3,
#   64,
#   9,
#   1967,
#   'вулиця',
#   'Подільський'),
#  ('Щекавицька',
#   5,
#   43,
#   1719.0,
#   110000.0,
#   3,
#   64,
#   9,
#   1967,
#   'площа',
#   'Подільський'),
#  ('Коласа', 4, 17, 1757.0, 65000.0, 1, 37, 27, 2019, None, None),
#  ('No street name', 15, 65, 2222.0, 260000.0, 3, 117, 20, 2019, None, None),
#  ('No street name', 6, 0, 2778.0, 125000.0, 2, 45, 9, 1965, None, None),
#  ('Перемоги',
#   9,
#   20,
#   1548.0,
#   65000.0,
#   1,
#   42,
#   16,
#   2020,
#   'вулиця',
#   'Святошинський'),
#  ('Перемоги',
#   9,
#   20,
#   1548.0,
#   65000.0,
#   1,
#   42,
#   16,
#   2020,
#   'площа',
#   'Шевченківський'),
#  ('Перемоги',
#   9,
#   20,
#   1548.0,
#   65000.0,
#   1,
#   42,
#   16,
#   2020,
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('No street name', 23, 60, 1374.0, 158000.0, 3, 115, 24, 2012, None, None),
#  ('Наумова', 29, 19, 1536.0, 80000.0, 1, 52.1, 36, 0, None, None),
#  ('Перемоги', 5, 0, 907.0, 68900.0, 3, 76, 5, 1963, 'вулиця', 'Святошинський'),
#  ('Перемоги', 5, 0, 907.0, 68900.0, 3, 76, 5, 1963, 'площа', 'Шевченківський'),
#  ('Перемоги',
#   5,
#   0,
#   907.0,
#   68900.0,
#   3,
#   76,
#   5,
#   1963,
#   'проспект',
#   "Шевченківський, Святошинський, Солом'янський"),
#  ('Велика', 19, 74, 1461.0, 168000.0, 4, 115, 20, 1995, None, None),
#  ('Червоноткацька', 11, 17.9, 1019.0, 41000.0, 1, 40.22, 25, 0, None, None),
#  ('Вишгородська',
#   7,
#   18.53,
#   2263.0,
#   134900.0,
#   1,
#   59.62,
#   11,
#   0,
#   'вулиця',
#   'Подільський, Оболонський')]

# %%
# створити запит для наповнення таблиці `result` результатом запиту на об'єднання
stmt_insert = "INSERT INTO street_result " + stmt_join

# %%
cur.execute(stmt_insert)

conn.commit()

conn.close()

# %%
# сберегти вміст створеної таблиці у вигляді списка
import sqlite3

conn = sqlite3.connect("districts.db")

cur = conn.cursor()

result_list = cur.execute("SELECT * FROM street_result").fetchall()

# %% [markdown]
# #### для аналізу скористатися бібліотекою NumPy

# %%
import numpy as np

# %%
# створити np-масив з списку `result_list`
jornal_test_list = cur.execute("SELECT * from street_result").fetchall()
jornal_test_arr = np.array(jornal_test_list)

x_result = np.delete(jornal_test_arr, [0,9,10], axis=1)
print(x_result)
# Out:
# [[21 37 1575.0 ... 25 2015 None]
#  [11 58 680.0 ... 25 0 None]
#  [5 56 1400.0 ... 18 2011 None]
#  ...
#  [19 74 1461.0 ... 20 1995 None]
#  [11 17.9 1019.0 ... 25 0 None]
#  [7 18.53 2263.0 ... 11 0 'Подільський, Оболонський']]

# %%
# побудувати словник для результатів аналізу
result_dict = {
    "кількість спостережень"   : len(test_result),
    "кількість пустих значень" : len(test_result) - np.count_nonzero(test_result),
    "середній бал"             : round(np.mean(test_result),1),
    "максимальний бал"         : np.max(test_result),
    "мінімальний бал"          : np.min(test_result[np.nonzero(test_result)]),
    "стандартне відхилення"    : round(np.std(test_result),1),
    "розмах вариації"          : np.max(test_result) - np.min(test_result[np.nonzero(test_result)]) 
    }

# %%
# вивести шапку
disctricts_list = cur.execute("SELECT DISTINCT district FROM street_result").fetchall()
for i in range(len(disctricts_list)):
    values = disctricts_list[i]
    district = values[0]   
    
    jornal_test_list = cur.execute("SELECT * from street_result WHERE district = ?", (district,)).fetchall()    
    jornal_test_arr = np.array(jornal_test_list)
    
    if(len(jornal_test_arr) == 0):
        continue
        
    x_result = np.delete(jornal_test_arr, [0,9,10], axis=1)
    
    length = x_result.shape
    columns_count = length[1]
    
    print("Назва району: " + district + '\n')
    
    for j in range(0, length[1]):
        test_result = x_result[:,j].astype(float)        
        try:
            result_dict = {
    "кількість спостережень"   : len(test_result),
    "кількість пустих значень" : len(test_result) - np.count_nonzero(test_result),
    "середній бал"             : round(np.mean(test_result),1),
    "максимальний бал"         : np.max(test_result),
    "мінімальний бал"          : np.min(test_result[np.nonzero(test_result)]) ,
    "стандартне відхилення"    : round(np.std(test_result),1),
    "розмах вариації"          : np.max(test_result) - np.min(test_result[np.nonzero(test_result)]) 
    }
        
        except ValueError: "Empty"
        pass
    
        columns_names = cur.execute("PRAGMA table_info('street_flat_propery')").fetchall()
        
        print("Назва поля: " + columns_names[j + 1][1])
        
        print(
"""
=======================================
№  : ПОКАЗЧИК               : ЗНАЧЕННЯ     
=======================================
"""      
      )
    
    

        k = 1
        for key, value in result_dict.items():
            print (f'{k:<3} {key:<25}  {value}')
            k += 1     
        
        print('\n')
        
    
    
    

# вивести результати аналізу датасета
# Out:
# Назва району: Подільський
#
# Назва поля: aprt_level
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     108
# 2   кількість пустих значень   3
# 3   середній бал               9.5
# 4   максимальний бал           26.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      6.6
# 7   розмах вариації            25.0
#
#
# Назва поля: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     108
# 2   кількість пустих значень   12
# 3   середній бал               30.9
# 4   максимальний бал           115.0
# 5   мінімальний бал            11.0
# 6   стандартне відхилення      22.7
# 7   розмах вариації            104.0
#
#
# Назва поля: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     108
# 2   кількість пустих значень   3
# 3   середній бал               5240.4
# 4   максимальний бал           58042.0
# 5   мінімальний бал            833.0
# 6   стандартне відхилення      12917.9
# 7   розмах вариації            57209.0
#
#
# Назва поля: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     108
# 2   кількість пустих значень   0
# 3   середній бал               116383.5
# 4   максимальний бал           750000.0
# 5   мінімальний бал            36500.0
# 6   стандартне відхилення      120804.0
# 7   розмах вариації            713500.0
#
#
# Назва поля: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     108
# 2   кількість пустих значень   0
# 3   середній бал               2.0
# 4   максимальний бал           5.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      1.0
# 7   розмах вариації            4.0
#
#
# Назва поля: aprt_total_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     108
# 2   кількість пустих значень   0
# 3   середній бал               71.8
# 4   максимальний бал           208.0
# 5   мінімальний бал            31.0
# 6   стандартне відхилення      37.1
# 7   розмах вариації            177.0
#
#
# Назва поля: aprt_total_levels
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     108
# 2   кількість пустих значень   3
# 3   середній бал               18.1
# 4   максимальний бал           33.0
# 5   мінімальний бал            5.0
# 6   стандартне відхилення      8.7
# 7   розмах вариації            28.0
#
#
# Назва поля: aprt_year
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     108
# 2   кількість пустих значень   30
# 3   середній бал               1441.0
# 4   максимальний бал           2019.0
# 5   мінімальний бал            1902.0
# 6   стандартне відхилення      894.0
# 7   розмах вариації            117.0
#
#
# Назва району: Оболонський
#
# Назва поля: aprt_level
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     153
# 2   кількість пустих значень   3
# 3   середній бал               10.6
# 4   максимальний бал           28.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      7.8
# 7   розмах вариації            27.0
#
#
# Назва поля: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     153
# 2   кількість пустих значень   21
# 3   середній бал               34.1
# 4   максимальний бал           115.0
# 5   мінімальний бал            14.0
# 6   стандартне відхилення      23.5
# 7   розмах вариації            101.0
#
#
# Назва поля: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     153
# 2   кількість пустих значень   0
# 3   середній бал               2642.4
# 4   максимальний бал           27503.0
# 5   мінімальний бал            796.0
# 6   стандартне відхилення      4829.4
# 7   розмах вариації            26707.0
#
#
# Назва поля: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     153
# 2   кількість пустих значень   0
# 3   середній бал               150635.0
# 4   максимальний бал           1400000.0
# 5   мінімальний бал            31891.891891891893
# 6   стандартне відхилення      207753.5
# 7   розмах вариації            1368108.1081081082
#
#
# Назва поля: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     153
# 2   кількість пустих значень   0
# 3   середній бал               2.2
# 4   максимальний бал           5.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      0.9
# 7   розмах вариації            4.0
#
#
# Назва поля: aprt_total_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     153
# 2   кількість пустих значень   0
# 3   середній бал               79.1
# 4   максимальний бал           312.0
# 5   мінімальний бал            25.0
# 6   стандартне відхилення      47.0
# 7   розмах вариації            287.0
#
#
# Назва поля: aprt_total_levels
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     153
# 2   кількість пустих значень   3
# 3   середній бал               17.4
# 4   максимальний бал           34.0
# 5   мінімальний бал            4.0
# 6   стандартне відхилення      8.6
# 7   розмах вариації            30.0
#
#
# Назва поля: aprt_year
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     153
# 2   кількість пустих значень   51
# 3   середній бал               1328.3
# 4   максимальний бал           2020.0
# 5   мінімальний бал            1902.0
# 6   стандартне відхилення      939.6
# 7   розмах вариації            118.0
#
#
# Назва району: Голосіївський, Печерський, Шевченківський
#
# Назва поля: aprt_level
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     21
# 2   кількість пустих значень   3
# 3   середній бал               5.9
# 4   максимальний бал           18.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      7.1
# 7   розмах вариації            17.0
#
#
# Назва поля: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     21
# 2   кількість пустих значень   3
# 3   середній бал               38.7
# 4   максимальний бал           77.6
# 5   мінімальний бал            18.0
# 6   стандартне відхилення      23.7
# 7   розмах вариації            59.599999999999994
#
#
# Назва поля: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     21
# 2   кількість пустих значень   3
# 3   середній бал               2186.9
# 4   максимальний бал           6273.0
# 5   мінімальний бал            878.0
# 6   стандартне відхилення      1886.1
# 7   розмах вариації            5395.0
#
#
# Назва поля: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     21
# 2   кількість пустих значень   0
# 3   середній бал               221620.3
# 4   максимальний бал           870000.0
# 5   мінімальний бал            65000.0
# 6   стандартне відхилення      268449.7
# 7   розмах вариації            805000.0
#
#
# Назва поля: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     21
# 2   кількість пустих значень   0
# 3   середній бал               2.3
# 4   максимальний бал           3.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      0.9
# 7   розмах вариації            2.0
#
#
# Назва поля: aprt_total_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     21
# 2   кількість пустих значень   0
# 3   середній бал               80.0
# 4   максимальний бал           138.7
# 5   мінімальний бал            45.0
# 6   стандартне відхилення      32.4
# 7   розмах вариації            93.69999999999999
#
#
# Назва поля: aprt_total_levels
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     21
# 2   кількість пустих значень   3
# 3   середній бал               12.6
# 4   максимальний бал           24.0
# 5   мінімальний бал            5.0
# 6   стандартне відхилення      8.5
# 7   розмах вариації            19.0
#
#
# Назва поля: aprt_year
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     21
# 2   кількість пустих значень   6
# 3   середній бал               1412.6
# 4   максимальний бал           2009.0
# 5   мінімальний бал            1916.0
# 6   стандартне відхилення      893.8
# 7   розмах вариації            93.0
#
#
# Назва району: Голосіївський, Печерський
#
# Назва поля: aprt_level
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     45
# 2   кількість пустих значень   6
# 3   середній бал               11.9
# 4   максимальний бал           24.0
# 5   мінімальний бал            2.0
# 6   стандартне відхилення      8.3
# 7   розмах вариації            22.0
#
#
# Назва поля: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     45
# 2   кількість пустих значень   12
# 3   середній бал               25.4
# 4   максимальний бал           65.0
# 5   мінімальний бал            10.0
# 6   стандартне відхилення      21.2
# 7   розмах вариації            55.0
#
#
# Назва поля: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     45
# 2   кількість пустих значень   6
# 3   середній бал               2597.5
# 4   максимальний бал           14610.0
# 5   мінімальний бал            602.0
# 6   стандартне відхилення      3489.3
# 7   розмах вариації            14008.0
#
#
# Назва поля: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     45
# 2   кількість пустих значень   0
# 3   середній бал               448877.5
# 4   максимальний бал           4500000.0
# 5   мінімальний бал            45006.0
# 6   стандартне відхилення      1093281.8
# 7   розмах вариації            4454994.0
#
#
# Назва поля: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     45
# 2   кількість пустих значень   3
# 3   середній бал               2.1
# 4   максимальний бал           4.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      1.1
# 7   розмах вариації            3.0
#
#
# Назва поля: aprt_total_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     45
# 2   кількість пустих значень   3
# 3   середній бал               85.3
# 4   максимальний бал           308.0
# 5   мінімальний бал            40.0
# 6   стандартне відхилення      69.8
# 7   розмах вариації            268.0
#
#
# Назва поля: aprt_total_levels
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     45
# 2   кількість пустих значень   6
# 3   середній бал               17.9
# 4   максимальний бал           27.0
# 5   мінімальний бал            4.0
# 6   стандартне відхилення      9.3
# 7   розмах вариації            23.0
#
#
# Назва поля: aprt_year
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     45
# 2   кількість пустих значень   24
# 3   середній бал               939.9
# 4   максимальний бал           2019.0
# 5   мінімальний бал            2006.0
# 6   стандартне відхилення      1004.8
# 7   розмах вариації            13.0
#
#
# Назва району: Дарницький
#
# Назва поля: aprt_level
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     198
# 2   кількість пустих значень   3
# 3   середній бал               10.5
# 4   максимальний бал           29.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      7.2
# 7   розмах вариації            28.0
#
#
# Назва поля: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     198
# 2   кількість пустих значень   45
# 3   середній бал               32.5
# 4   максимальний бал           115.0
# 5   мінімальний бал            13.61
# 6   стандартне відхилення      30.5
# 7   розмах вариації            101.39
#
#
# Назва поля: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     198
# 2   кількість пустих значень   3
# 3   середній бал               1817.3
# 4   максимальний бал           6522.0
# 5   мінімальний бал            927.0
# 6   стандартне відхилення      1011.1
# 7   розмах вариації            5595.0
#
#
# Назва поля: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     198
# 2   кількість пустих значень   0
# 3   середній бал               168472.7
# 4   максимальний бал           1500000.0
# 5   мінімальний бал            36500.0
# 6   стандартне відхилення      214619.1
# 7   розмах вариації            1463500.0
#
#
# Назва поля: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     198
# 2   кількість пустих значень   0
# 3   середній бал               2.1
# 4   максимальний бал           5.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      1.0
# 7   розмах вариації            4.0
#
#
# Назва поля: aprt_total_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     198
# 2   кількість пустих значень   0
# 3   середній бал               79.7
# 4   максимальний бал           230.0
# 5   мінімальний бал            28.0
# 6   стандартне відхилення      45.1
# 7   розмах вариації            202.0
#
#
# Назва поля: aprt_total_levels
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     198
# 2   кількість пустих значень   3
# 3   середній бал               17.4
# 4   максимальний бал           33.0
# 5   мінімальний бал            3.0
# 6   стандартне відхилення      8.2
# 7   розмах вариації            30.0
#
#
# Назва поля: aprt_year
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     198
# 2   кількість пустих значень   51
# 3   середній бал               1485.3
# 4   максимальний бал           2020.0
# 5   мінімальний бал            1914.0
# 6   стандартне відхилення      875.1
# 7   розмах вариації            106.0
#
#
# Назва району: Печерський
#
# Назва поля: aprt_level
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     108
# 2   кількість пустих значень   6
# 3   середній бал               8.8
# 4   максимальний бал           25.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      7.1
# 7   розмах вариації            24.0
#
#
# Назва поля: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     108
# 2   кількість пустих значень   12
# 3   середній бал               33.2
# 4   максимальний бал           80.0
# 5   мінімальний бал            14.1
# 6   стандартне відхилення      21.6
# 7   розмах вариації            65.9
#
#
# Назва поля: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     108
# 2   кількість пустих значень   0
# 3   середній бал               2771.2
# 4   максимальний бал           33177.0
# 5   мінімальний бал            781.0
# 6   стандартне відхилення      5236.2
# 7   розмах вариації            32396.0
#
#
# Назва поля: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     108
# 2   кількість пустих значень   0
# 3   середній бал               150588.4
# 4   максимальний бал           500000.0
# 5   мінімальний бал            42900.0
# 6   стандартне відхилення      113433.7
# 7   розмах вариації            457100.0
#
#
# Назва поля: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     108
# 2   кількість пустих значень   0
# 3   середній бал               2.1
# 4   максимальний бал           4.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      1.0
# 7   розмах вариації            3.0
#
#
# Назва поля: aprt_total_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     108
# 2   кількість пустих значень   0
# 3   середній бал               79.6
# 4   максимальний бал           210.0
# 5   мінімальний бал            37.62
# 6   стандартне відхилення      40.5
# 7   розмах вариації            172.38
#
#
# Назва поля: aprt_total_levels
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     108
# 2   кількість пустих значень   6
# 3   середній бал               15.6
# 4   максимальний бал           27.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      9.3
# 7   розмах вариації            26.0
#
#
# Назва поля: aprt_year
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     108
# 2   кількість пустих значень   42
# 3   середній бал               1215.5
# 4   максимальний бал           2019.0
# 5   мінімальний бал            1892.0
# 6   стандартне відхилення      970.1
# 7   розмах вариації            127.0
#
#
# Назва району: Голосіївський,Солом'янський
#
# Назва поля: aprt_level
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     9
# 2   кількість пустих значень   0
# 3   середній бал               13.3
# 4   максимальний бал           20.0
# 5   мінімальний бал            5.0
# 6   стандартне відхилення      6.2
# 7   розмах вариації            15.0
#
#
# Назва поля: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     9
# 2   кількість пустих значень   3
# 3   середній бал               24.2
# 4   максимальний бал           44.0
# 5   мінімальний бал            28.74
# 6   стандартне відхилення      18.2
# 7   розмах вариації            15.260000000000002
#
#
# Назва поля: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     9
# 2   кількість пустих значень   0
# 3   середній бал               1608.0
# 4   максимальний бал           2720.0
# 5   мінімальний бал            933.0
# 6   стандартне відхилення      792.3
# 7   розмах вариації            1787.0
#
#
# Назва поля: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     9
# 2   кількість пустих значень   0
# 3   середній бал               93166.7
# 4   максимальний бал           136000.0
# 5   мінімальний бал            61500.0
# 6   стандартне відхилення      31422.7
# 7   розмах вариації            74500.0
#
#
# Назва поля: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     9
# 2   кількість пустих значень   0
# 3   середній бал               2.3
# 4   максимальний бал           3.0
# 5   мінімальний бал            2.0
# 6   стандартне відхилення      0.5
# 7   розмах вариації            1.0
#
#
# Назва поля: aprt_total_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     9
# 2   кількість пустих значень   0
# 3   середній бал               62.0
# 4   максимальний бал           70.0
# 5   мінімальний бал            50.0
# 6   стандартне відхилення      8.6
# 7   розмах вариації            20.0
#
#
# Назва поля: aprt_total_levels
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     9
# 2   кількість пустих значень   0
# 3   середній бал               20.0
# 4   максимальний бал           26.0
# 5   мінімальний бал            9.0
# 6   стандартне відхилення      7.8
# 7   розмах вариації            17.0
#
#
# Назва поля: aprt_year
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     9
# 2   кількість пустих значень   3
# 3   середній бал               1332.3
# 4   максимальний бал           2016.0
# 5   мінімальний бал            1981.0
# 6   стандартне відхилення      942.2
# 7   розмах вариації            35.0
#
#
# Назва району: Голосіївський
#
# Назва поля: aprt_level
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     126
# 2   кількість пустих значень   6
# 3   середній бал               10.9
# 4   максимальний бал           28.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      8.6
# 7   розмах вариації            27.0
#
#
# Назва поля: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     126
# 2   кількість пустих значень   36
# 3   середній бал               34.0
# 4   максимальний бал           150.0
# 5   мінімальний бал            14.0
# 6   стандартне відхилення      35.1
# 7   розмах вариації            136.0
#
#
# Назва поля: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     126
# 2   кількість пустих значень   6
# 3   середній бал               3442.7
# 4   максимальний бал           43400.0
# 5   мінімальний бал            822.0
# 6   стандартне відхилення      7235.5
# 7   розмах вариації            42578.0
#
#
# Назва поля: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     126
# 2   кількість пустих значень   0
# 3   середній бал               179073.8
# 4   максимальний бал           980000.0
# 5   мінімальний бал            38000.0
# 6   стандартне відхилення      203478.3
# 7   розмах вариації            942000.0
#
#
# Назва поля: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     126
# 2   кількість пустих значень   0
# 3   середній бал               2.3
# 4   максимальний бал           5.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      0.9
# 7   розмах вариації            4.0
#
#
# Назва поля: aprt_total_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     126
# 2   кількість пустих значень   0
# 3   середній бал               84.2
# 4   максимальний бал           213.0
# 5   мінімальний бал            43.0
# 6   стандартне відхилення      45.4
# 7   розмах вариації            170.0
#
#
# Назва поля: aprt_total_levels
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     126
# 2   кількість пустих значень   6
# 3   середній бал               15.9
# 4   максимальний бал           34.0
# 5   мінімальний бал            4.0
# 6   стандартне відхилення      9.1
# 7   розмах вариації            30.0
#
#
# Назва поля: aprt_year
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     126
# 2   кількість пустих значень   27
# 3   середній бал               1570.4
# 4   максимальний бал           2019.0
# 5   мінімальний бал            1906.0
# 6   стандартне відхилення      820.4
# 7   розмах вариації            113.0
#
#
# Назва району: Солом'янський
#
# Назва поля: aprt_level
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     96
# 2   кількість пустих значень   9
# 3   середній бал               10.7
# 4   максимальний бал           26.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      8.2
# 7   розмах вариації            25.0
#
#
# Назва поля: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     96
# 2   кількість пустих значень   15
# 3   середній бал               30.5
# 4   максимальний бал           150.0
# 5   мінімальний бал            14.1
# 6   стандартне відхилення      29.4
# 7   розмах вариації            135.9
#
#
# Назва поля: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     96
# 2   кількість пустих значень   0
# 3   середній бал               3869.9
# 4   максимальний бал           34954.0
# 5   мінімальний бал            827.0
# 6   стандартне відхилення      8049.6
# 7   розмах вариації            34127.0
#
#
# Назва поля: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     96
# 2   кількість пустих значень   0
# 3   середній бал               139328.5
# 4   максимальний бал           750000.0
# 5   мінімальний бал            39677.48648648649
# 6   стандартне відхилення      139190.0
# 7   розмах вариації            710322.5135135135
#
#
# Назва поля: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     96
# 2   кількість пустих значень   0
# 3   середній бал               1.8
# 4   максимальний бал           5.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      1.0
# 7   розмах вариації            4.0
#
#
# Назва поля: aprt_total_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     96
# 2   кількість пустих значень   0
# 3   середній бал               70.5
# 4   максимальний бал           248.0
# 5   мінімальний бал            33.0
# 6   стандартне відхилення      42.3
# 7   розмах вариації            215.0
#
#
# Назва поля: aprt_total_levels
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     96
# 2   кількість пустих значень   9
# 3   середній бал               17.3
# 4   максимальний бал           30.0
# 5   мінімальний бал            4.0
# 6   стандартне відхилення      9.4
# 7   розмах вариації            26.0
#
#
# Назва поля: aprt_year
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     96
# 2   кількість пустих значень   39
# 3   середній бал               1190.9
# 4   максимальний бал           2022.0
# 5   мінімальний бал            1962.0
# 6   стандартне відхилення      985.2
# 7   розмах вариації            60.0
#
#
# Назва району: Святошинський
#
# Назва поля: aprt_level
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     111
# 2   кількість пустих значень   6
# 3   середній бал               8.2
# 4   максимальний бал           25.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      7.3
# 7   розмах вариації            24.0
#
#
# Назва поля: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     111
# 2   кількість пустих значень   27
# 3   середній бал               29.8
# 4   максимальний бал           101.0
# 5   мінімальний бал            15.0
# 6   стандартне відхилення      25.1
# 7   розмах вариації            86.0
#
#
# Назва поля: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     111
# 2   кількість пустих значень   3
# 3   середній бал               2586.0
# 4   максимальний бал           30000.0
# 5   мінімальний бал            534.0
# 6   стандартне відхилення      4841.3
# 7   розмах вариації            29466.0
#
#
# Назва поля: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     111
# 2   кількість пустих значень   0
# 3   середній бал               205595.0
# 4   максимальний бал           3400000.0
# 5   мінімальний бал            21810.81081081081
# 6   стандартне відхилення      540712.4
# 7   розмах вариації            3378189.189189189
#
#
# Назва поля: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     111
# 2   кількість пустих значень   0
# 3   середній бал               2.3
# 4   максимальний бал           5.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      1.0
# 7   розмах вариації            4.0
#
#
# Назва поля: aprt_total_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     111
# 2   кількість пустих значень   0
# 3   середній бал               77.3
# 4   максимальний бал           340.0
# 5   мінімальний бал            25.0
# 6   стандартне відхилення      55.0
# 7   розмах вариації            315.0
#
#
# Назва поля: aprt_total_levels
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     111
# 2   кількість пустих значень   6
# 3   середній бал               14.4
# 4   максимальний бал           34.0
# 5   мінімальний бал            4.0
# 6   стандартне відхилення      9.2
# 7   розмах вариації            30.0
#
#
# Назва поля: aprt_year
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     111
# 2   кількість пустих значень   42
# 3   середній бал               1243.3
# 4   максимальний бал           2020.0
# 5   мінімальний бал            1961.0
# 6   стандартне відхилення      970.2
# 7   розмах вариації            59.0
#
#
# Назва району: Шевченківський
#
# Назва поля: aprt_level
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     165
# 2   кількість пустих значень   3
# 3   середній бал               9.0
# 4   максимальний бал           25.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      7.0
# 7   розмах вариації            24.0
#
#
# Назва поля: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     165
# 2   кількість пустих значень   21
# 3   середній бал               35.4
# 4   максимальний бал           120.0
# 5   мінімальний бал            14.0
# 6   стандартне відхилення      23.7
# 7   розмах вариації            106.0
#
#
# Назва поля: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     165
# 2   кількість пустих значень   0
# 3   середній бал               2592.9
# 4   максимальний бал           55506.0
# 5   мінімальний бал            717.0
# 6   стандартне відхилення      7244.9
# 7   розмах вариації            54789.0
#
#
# Назва поля: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     165
# 2   кількість пустих значень   0
# 3   середній бал               122064.1
# 4   максимальний бал           422000.0
# 5   мінімальний бал            31500.0
# 6   стандартне відхилення      85683.8
# 7   розмах вариації            390500.0
#
#
# Назва поля: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     165
# 2   кількість пустих значень   0
# 3   середній бал               2.3
# 4   максимальний бал           5.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      1.0
# 7   розмах вариації            4.0
#
#
# Назва поля: aprt_total_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     165
# 2   кількість пустих значень   0
# 3   середній бал               74.0
# 4   максимальний бал           198.5
# 5   мінімальний бал            32.1
# 6   стандартне відхилення      32.9
# 7   розмах вариації            166.4
#
#
# Назва поля: aprt_total_levels
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     165
# 2   кількість пустих значень   3
# 3   середній бал               16.9
# 4   максимальний бал           34.0
# 5   мінімальний бал            4.0
# 6   стандартне відхилення      8.7
# 7   розмах вариації            30.0
#
#
# Назва поля: aprt_year
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     165
# 2   кількість пустих значень   51
# 3   середній бал               1375.6
# 4   максимальний бал           2020.0
# 5   мінімальний бал            1936.0
# 6   стандартне відхилення      920.3
# 7   розмах вариації            84.0
#
#
# Назва району: Шевченківський, Святошинський, Солом'янський
#
# Назва поля: aprt_level
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     39
# 2   кількість пустих значень   0
# 3   середній бал               7.2
# 4   максимальний бал           16.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      4.6
# 7   розмах вариації            15.0
#
#
# Назва поля: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     39
# 2   кількість пустих значень   9
# 3   середній бал               26.5
# 4   максимальний бал           68.0
# 5   мінімальний бал            17.0
# 6   стандартне відхилення      19.9
# 7   розмах вариації            51.0
#
#
# Назва поля: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     39
# 2   кількість пустих значень   0
# 3   середній бал               1793.2
# 4   максимальний бал           4637.0
# 5   мінімальний бал            878.0
# 6   стандартне відхилення      1096.9
# 7   розмах вариації            3759.0
#
#
# Назва поля: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     39
# 2   кількість пустих значень   0
# 3   середній бал               117915.4
# 4   максимальний бал           422000.0
# 5   мінімальний бал            39000.0
# 6   стандартне відхилення      100833.7
# 7   розмах вариації            383000.0
#
#
# Назва поля: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     39
# 2   кількість пустих значень   0
# 3   середній бал               2.2
# 4   максимальний бал           3.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      0.7
# 7   розмах вариації            2.0
#
#
# Назва поля: aprt_total_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     39
# 2   кількість пустих значень   0
# 3   середній бал               62.4
# 4   максимальний бал           98.0
# 5   мінімальний бал            32.1
# 6   стандартне відхилення      21.2
# 7   розмах вариації            65.9
#
#
# Назва поля: aprt_total_levels
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     39
# 2   кількість пустих значень   0
# 3   середній бал               12.8
# 4   максимальний бал           34.0
# 5   мінімальний бал            5.0
# 6   стандартне відхилення      8.8
# 7   розмах вариації            29.0
#
#
# Назва поля: aprt_year
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     39
# 2   кількість пустих значень   12
# 3   середній бал               1376.7
# 4   максимальний бал           2020.0
# 5   мінімальний бал            1961.0
# 6   стандартне відхилення      918.0
# 7   розмах вариації            59.0
#
#
# Назва району: Деснянський, Дніпровський
#
# Назва поля: aprt_level
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   0
# 3   середній бал               4.0
# 4   максимальний бал           6.0
# 5   мінімальний бал            2.0
# 6   стандартне відхилення      2.0
# 7   розмах вариації            4.0
#
#
# Назва поля: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   0
# 3   середній бал               142.5
# 4   максимальний бал           240.0
# 5   мінімальний бал            45.0
# 6   стандартне відхилення      97.5
# 7   розмах вариації            195.0
#
#
# Назва поля: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   0
# 3   середній бал               3947.0
# 4   максимальний бал           5000.0
# 5   мінімальний бал            2894.0
# 6   стандартне відхилення      1053.0
# 7   розмах вариації            2106.0
#
#
# Назва поля: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   0
# 3   середній бал               645000.0
# 4   максимальний бал           790000.0
# 5   мінімальний бал            500000.0
# 6   стандартне відхилення      145000.0
# 7   розмах вариації            290000.0
#
#
# Назва поля: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   0
# 3   середній бал               4.5
# 4   максимальний бал           6.0
# 5   мінімальний бал            3.0
# 6   стандартне відхилення      1.5
# 7   розмах вариації            3.0
#
#
# Назва поля: aprt_total_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   0
# 3   середній бал               186.5
# 4   максимальний бал           273.0
# 5   мінімальний бал            100.0
# 6   стандартне відхилення      86.5
# 7   розмах вариації            173.0
#
#
# Назва поля: aprt_total_levels
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   0
# 3   середній бал               5.5
# 4   максимальний бал           6.0
# 5   мінімальний бал            5.0
# 6   стандартне відхилення      0.5
# 7   розмах вариації            1.0
#
#
# Назва поля: aprt_year
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   0
# 3   середній бал               1903.0
# 4   максимальний бал           1914.0
# 5   мінімальний бал            1892.0
# 6   стандартне відхилення      11.0
# 7   розмах вариації            22.0
#
#
# Назва району: Дніпровський
#
# Назва поля: aprt_level
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     96
# 2   кількість пустих значень   15
# 3   середній бал               6.2
# 4   максимальний бал           22.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      6.1
# 7   розмах вариації            21.0
#
#
# Назва поля: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     96
# 2   кількість пустих значень   27
# 3   середній бал               32.1
# 4   максимальний бал           137.0
# 5   мінімальний бал            13.0
# 6   стандартне відхилення      34.3
# 7   розмах вариації            124.0
#
#
# Назва поля: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     96
# 2   кількість пустих значень   6
# 3   середній бал               2835.4
# 4   максимальний бал           25808.0
# 5   мінімальний бал            710.0
# 6   стандартне відхилення      4670.4
# 7   розмах вариації            25098.0
#
#
# Назва поля: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     96
# 2   кількість пустих значень   0
# 3   середній бал               336274.1
# 4   максимальний бал           3400000.0
# 5   мінімальний бал            21162.162162162163
# 6   стандартне відхилення      798172.0
# 7   розмах вариації            3378837.8378378376
#
#
# Назва поля: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     96
# 2   кількість пустих значень   0
# 3   середній бал               2.4
# 4   максимальний бал           5.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      1.2
# 7   розмах вариації            4.0
#
#
# Назва поля: aprt_total_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     96
# 2   кількість пустих значень   0
# 3   середній бал               92.6
# 4   максимальний бал           340.0
# 5   мінімальний бал            24.0
# 6   стандартне відхилення      76.3
# 7   розмах вариації            316.0
#
#
# Назва поля: aprt_total_levels
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     96
# 2   кількість пустих значень   15
# 3   середній бал               13.5
# 4   максимальний бал           35.0
# 5   мінімальний бал            5.0
# 6   стандартне відхилення      10.4
# 7   розмах вариації            30.0
#
#
# Назва поля: aprt_year
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     96
# 2   кількість пустих значень   36
# 3   середній бал               1242.8
# 4   максимальний бал           2019.0
# 5   мінімальний бал            1936.0
# 6   стандартне відхилення      962.8
# 7   розмах вариації            83.0
#
#
# Назва району: Дніпровський, Деснянський
#
# Назва поля: aprt_level
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               9.0
# 4   максимальний бал           9.0
# 5   мінімальний бал            9.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               39.7
# 4   максимальний бал           39.7
# 5   мінімальний бал            39.7
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               966.0
# 4   максимальний бал           966.0
# 5   мінімальний бал            966.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               65000.0
# 4   максимальний бал           65000.0
# 5   мінімальний бал            65000.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               3.0
# 4   максимальний бал           3.0
# ...
# 5   мінімальний бал            20.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               20.9
# 4   максимальний бал           20.9
# 5   мінімальний бал            20.9
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               2022.0
# 4   максимальний бал           2022.0
# 5   мінімальний бал            2022.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               93000.0
# 4   максимальний бал           93000.0
# 5   мінімальний бал            93000.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               1.0
# 4   максимальний бал           1.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_total_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               46.0
# 4   максимальний бал           46.0
# 5   мінімальний бал            46.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_total_levels
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               24.0
# 4   максимальний бал           24.0
# 5   мінімальний бал            24.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_year
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               24.0
# 4   максимальний бал           24.0
# 5   мінімальний бал            24.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва району: Солом'янський, Шевченківський
#
# Назва поля: aprt_level
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   3
# 3   середній бал               5.0
# 4   максимальний бал           10.0
# 5   мінімальний бал            10.0
# 6   стандартне відхилення      5.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   3
# 3   середній бал               14.5
# 4   максимальний бал           29.0
# 5   мінімальний бал            29.0
# 6   стандартне відхилення      14.5
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   3
# 3   середній бал               865.0
# 4   максимальний бал           1730.0
# 5   мінімальний бал            1730.0
# 6   стандартне відхилення      865.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   0
# 3   середній бал               96159.5
# 4   максимальний бал           97319.02702702704
# 5   мінімальний бал            95000.0
# 6   стандартне відхилення      1159.5
# 7   розмах вариації            2319.027027027041
#
#
# Назва поля: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   0
# 3   середній бал               2.0
# 4   максимальний бал           2.0
# 5   мінімальний бал            2.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_total_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   0
# 3   середній бал               61.4
# 4   максимальний бал           68.0
# 5   мінімальний бал            54.9
# 6   стандартне відхилення      6.6
# 7   розмах вариації            13.100000000000001
#
#
# Назва поля: aprt_total_levels
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   3
# 3   середній бал               8.0
# 4   максимальний бал           16.0
# 5   мінімальний бал            16.0
# 6   стандартне відхилення      8.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_year
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   3
# 3   середній бал               996.5
# 4   максимальний бал           1993.0
# 5   мінімальний бал            1993.0
# 6   стандартне відхилення      996.5
# 7   розмах вариації            0.0
#
#
# Назва району: Печерський, Голосіївський, Шевченківський
#
# Назва поля: aprt_level
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               5.0
# 4   максимальний бал           5.0
# 5   мінімальний бал            5.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               25.0
# 4   максимальний бал           25.0
# 5   мінімальний бал            25.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               1268.0
# 4   максимальний бал           1268.0
# 5   мінімальний бал            1268.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               52000.0
# 4   максимальний бал           52000.0
# 5   мінімальний бал            52000.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               2.0
# 4   максимальний бал           2.0
# 5   мінімальний бал            2.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_total_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               41.0
# 4   максимальний бал           41.0
# 5   мінімальний бал            41.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_total_levels
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               5.0
# 4   максимальний бал           5.0
# 5   мінімальний бал            5.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_year
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               5.0
# 4   максимальний бал           5.0
# 5   мінімальний бал            5.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва району: Голосіївський, Шевченківський
#
# Назва поля: aprt_level
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               4.0
# 4   максимальний бал           4.0
# 5   мінімальний бал            4.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               43.2
# 4   максимальний бал           43.2
# 5   мінімальний бал            43.2
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               2068.0
# 4   максимальний бал           2068.0
# 5   мінімальний бал            2068.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               170000.0
# 4   максимальний бал           170000.0
# 5   мінімальний бал            170000.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               3.0
# 4   максимальний бал           3.0
# 5   мінімальний бал            3.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_total_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               82.2
# 4   максимальний бал           82.2
# 5   мінімальний бал            82.2
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_total_levels
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               5.0
# 4   максимальний бал           5.0
# 5   мінімальний бал            5.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_year
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     3
# 2   кількість пустих значень   0
# 3   середній бал               1910.0
# 4   максимальний бал           1910.0
# 5   мінімальний бал            1910.0
# 6   стандартне відхилення      0.0
# 7   розмах вариації            0.0
#
#
# Назва району: Печерський, Шевченківський
#
# Назва поля: aprt_level
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   3
# 3   середній бал               1.5
# 4   максимальний бал           3.0
# 5   мінімальний бал            3.0
# 6   стандартне відхилення      1.5
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_living_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   3
# 3   середній бал               28.5
# 4   максимальний бал           57.0
# 5   мінімальний бал            57.0
# 6   стандартне відхилення      28.5
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_pricepermether
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   3
# 3   середній бал               532.0
# 4   максимальний бал           1064.0
# 5   мінімальний бал            1064.0
# 6   стандартне відхилення      532.0
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_prices
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   0
# 3   середній бал               93906.2
# 4   максимальний бал           100000.0
# 5   мінімальний бал            87812.32432432432
# 6   стандартне відхилення      6093.8
# 7   розмах вариації            12187.67567567568
#
#
# Назва поля: aprt_rooms
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   0
# 3   середній бал               2.0
# 4   максимальний бал           3.0
# 5   мінімальний бал            1.0
# 6   стандартне відхилення      1.0
# 7   розмах вариації            2.0
#
#
# Назва поля: aprt_total_area
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   0
# 3   середній бал               75.0
# 4   максимальний бал           94.0
# 5   мінімальний бал            56.0
# 6   стандартне відхилення      19.0
# 7   розмах вариації            38.0
#
#
# Назва поля: aprt_total_levels
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   3
# 3   середній бал               12.5
# 4   максимальний бал           25.0
# 5   мінімальний бал            25.0
# 6   стандартне відхилення      12.5
# 7   розмах вариації            0.0
#
#
# Назва поля: aprt_year
#
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
#
# 1   кількість спостережень     6
# 2   кількість пустих значень   3
# 3   середній бал               1008.5
# 4   максимальний бал           2017.0
# 5   мінімальний бал            2017.0
# 6   стандартне відхилення      1008.5
# 7   розмах вариації            0.0
